# %% [raw]
# import sys
# !{sys.executable} -m pip install opendatasets

# %%
    1. Data
        The project should use a real-world dataset and include a reference to thesource in the report - DONE
    2. Importing
        Import data from a flat file (.csv, .xls, xlsx, .txt, etc.) - DONE
        Retrieve data using online SQL, APIs, or web scraping - DONE - kaggle pull and FIFA ranking scrape
    3. Preparation
        Create pandas DataFrame - DONE
        Sorting, indexing, grouping - NO SORT NO INDEX READ INTO THESE
        Drop duplicates, replace missing values - NO DROP DUP NO REPLACE MISS
        Merge DataFrames - DONE
    4. Analysis
        Conditional statements, looping, groupby - NO COND OR LOOP DO THIS IN SQUAD FUNCTION, YES GROUPING
        Define a custom function to create reusable code - TO DO FOR MATCH FUNCTIONS
        Use NumPy functions - NO NUMPY
        Dictionary or Lists - LISTS USED FOR WC TEAMS
    5. Visualisation
        Generate at least two charts using Matplotlib or Seaborn - YES DESCRIBED BELOW, DO SOME ADD ANALYSIS ONES AT BEGINNING IE DIST (WC TEAMS AND NOT) ETC
    6. Insights
        Derive five valuable insights from the analysis - BEST TEAMS ARE HIGH VAL+LUES RATINGS STRENGTH ETC
        Justify your insights with reference to the charts or analysis _ USE GRAPHS
    7. Machine Learning
        Describe what kind of prediction you could perform in future using machine learning and/or deep learning. - INCLUDE MORE DTA IE OLD WORLD CUP EVEN CLUB MATCHES
        Would you use classification or regression methods? - NO TO LOOK INTO

# %%
## plan

Take each player:
    Group by Position:
        Weighted forumla that is normalised 70-100 between:
            World Cup Value - player value (average of four years)
            Current transfermarkt summised value
            Current fifa rating
            Potential Rating
        Get each players rating.
    Group by Nationality
        Take the best X players for each position (ie: 3 goalkeeper etc)
        Build a 25 man squad (look for players not included from lower clubs that have been ommited (added these back in seperatley) maybe come back and do fulls scope of players)
    Create a squad rating
        DEF rating
        MID rating
        ATT rating
        FIFA world ranking - web scrape
    Create function that will play each against eachother
        Play group stages loaded in
        Play round of 16
        Play round of 8
        Play semis
        Play final
            Form Increased if you win
                For each match:
                    Team rating will increase/remain/decrease per result (will need recalculated):
                    Win +2 per rating
                    Draw 0 per rating
                    Loss -1 per rating
Visuals of best team on average with:
    Team Averages:
        Strength
        Skills 
        Etc
    Best and Worst Team XI's: 
        (Copy FYP) - use the image links
        Overall
        Potential etc
    Best Players not included in the 25 man squad
    Best Players in last couple World Cups
    Compare my rankins to FIFA ranks
# Out:
#   File "/var/folders/2d/6361wtyx7h51kz0b56dmjd_80000gn/T/ipykernel_1817/174641394.py", line 3
#     Take each player:
#          ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
import opendatasets as od

import random
from scipy.stats import norm

# %% [markdown]
# ### Loading Data in from Kaggle API

# %% [markdown]
# f51999f5f297523ab16349d4112bd4ff

# %%
od.download("https://www.kaggle.com/datasets/davidcariboo/player-scores")
# Out:
# Skipping, found downloaded files in "./player-scores" (use force=True to force download)

# %% [markdown]
# ### Reading in the Kaggle tables for Transfer Markt

# %%
valuations = (r'/Users/mallon/Desktop/UCD Data Analytics for Finance/player-scores/player_valuations.csv')
players = (r'/Users/mallon/Desktop/UCD Data Analytics for Finance/player-scores/players.csv')
competitions = (r'/Users/mallon/Desktop/UCD Data Analytics for Finance/player-scores/competitions.csv')
clubs = (r'/Users/mallon/Desktop/UCD Data Analytics for Finance/player-scores/clubs.csv')

# %%
players= pd.read_csv(players)
valuations= pd.read_csv(valuations)
competitions= pd.read_csv(competitions)
clubs= pd.read_csv(clubs)

# %%
#current players only
still_playing = players['last_season'] == 2022
players = players[still_playing]
players.head()
# Out:
#        player_id          pretty_name  club_id     club_pretty_name  \
# 19008     519731               Danilo      234  Feyenoord Rotterdam
# 19009     552955     Santiago Gimenez      234  Feyenoord Rotterdam
# 19010     213268  Alireza Jahanbakhsh      234  Feyenoord Rotterdam
# 19011     212391          Roger Marti     1531             Fc Elche
# 19012     913387      Danylo Kolesnyk    61825             Fk Minaj
#
#        current_club_id country_of_citizenship country_of_birth date_of_birth  \
# 19008              234                 Brazil           Brazil    1999-04-07
# 19009              234                 Mexico        Argentina    2001-04-18
# 19010              234                   Iran             Iran    1993-08-11
# 19011             1531                  Spain            Spain    1991-01-03
# 19012            61825                Ukraine              NaN    2001-09-22
#
#       position    sub_position  ... height_in_cm market_value_in_gbp  \
# 19008   Attack  Centre-Forward  ...          174           5000000.0
# 19009   Attack  Centre-Forward  ...          183           6000000.0
# 19010   Attack    Right Winger  ...          180           3000000.0
# 19011   Attack  Centre-Forward  ...          179           2500000.0
# 19012   Attack  Centre-Forward  ...          188             50000.0
#
#        highest_market_value_in_gbp                     agent_name  \
# 19008                    5000000.0                            SEG
# 19009                    6000000.0  CANTERA LATINA / MATIAS BUNGE
# 19010                   18000000.0                           AFFG
# 19011                   10000000.0                    Promoesport
# 19012                      50000.0                            NaN
#
#        contract_expiration_date domestic_competition_id            club_name  \
# 19008                2026-06-30                     NL1  feyenoord-rotterdam
# 19009                2026-06-30                     NL1  feyenoord-rotterdam
# 19010                2024-06-30                     NL1  feyenoord-rotterdam
# 19011                2026-06-30                     ES1             fc-elche
# 19012                2024-06-30                    UKR1             fk-minaj
#
#                                                image_url last_season  \
# 19008  https://img.a.transfermarkt.technology/portrai...        2022
# 19009  https://img.a.transfermarkt.technology/portrai...        2022
# 19010  https://img.a.transfermarkt.technology/portrai...        2022
# 19011  https://img.a.transfermarkt.technology/portrai...        2022
# 19012  https://img.a.transfermarkt.technology/portrai...        2022
#
#                                                      url
# 19008  https://www.transfermarkt.co.uk/danilo/profil/...
# 19009  https://www.transfermarkt.co.uk/santiago-gimen...
# 19010  https://www.transfermarkt.co.uk/alireza-jahanb...
# 19011  https://www.transfermarkt.co.uk/roger-marti/pr...
# 19012  https://www.transfermarkt.co.uk/danylo-kolesny...
#
# [5 rows x 22 columns]

# %%
valuations.head()
# Out:
#          date    datetime    dateweek  player_id  current_club_id  \
# 0  2013-07-22  2013-07-22  2013-07-22     254016              855
# 1  2014-01-14  2014-01-14  2014-01-13     254016              855
# 2  2008-08-25  2008-08-25  2008-08-25      51053               23
# 3  2011-05-30  2011-05-30  2011-05-30      51053               23
# 4  2011-08-26  2011-08-26  2011-08-22      51053               23
#
#    market_value player_club_domestic_competition_id
# 0         90000                                 FR1
# 1         90000                                 FR1
# 2         90000                                  L1
# 3         90000                                  L1
# 4        225000                                  L1

# %%
joined = pd.merge(left = players, right = valuations, how = 'inner', on = 'player_id' )
#firsttierplayersonly (revise later if no players for country)
joined = pd.merge(left = joined, right = clubs, how = 'inner', on = 'club_id' )
joined = pd.merge(left = joined, right = competitions, how = 'inner', left_on='player_club_domestic_competition_id', right_on='competition_id' )

# %%
first_tier = joined['sub_type'] == 'first_tier'
toptierplayers = joined[first_tier]

# %%
toptierplayers.head()
# Out:
#    player_id pretty_name_x  club_id     club_pretty_name  current_club_id_x  \
# 0     519731        Danilo      234  Feyenoord Rotterdam                234
# 1     519731        Danilo      234  Feyenoord Rotterdam                234
# 2     519731        Danilo      234  Feyenoord Rotterdam                234
# 3     519731        Danilo      234  Feyenoord Rotterdam                234
# 4     519731        Danilo      234  Feyenoord Rotterdam                234
#
#   country_of_citizenship country_of_birth date_of_birth position  \
# 0                 Brazil           Brazil    1999-04-07   Attack
# 1                 Brazil           Brazil    1999-04-07   Attack
# 2                 Brazil           Brazil    1999-04-07   Attack
# 3                 Brazil           Brazil    1999-04-07   Attack
# 4                 Brazil           Brazil    1999-04-07   Attack
#
#      sub_position  ...             type    sub_type  country_id  country_name  \
# 0  Centre-Forward  ...  domestic_league  first_tier         122   Netherlands
# 1  Centre-Forward  ...  domestic_league  first_tier         122   Netherlands
# 2  Centre-Forward  ...  domestic_league  first_tier         122   Netherlands
# 3  Centre-Forward  ...  domestic_league  first_tier         122   Netherlands
# 4  Centre-Forward  ...  domestic_league  first_tier         122   Netherlands
#
#    country_latitude country_longitude domestic_league_code        name  \
# 0         52.243498          5.634323                  NL1  eredivisie
# 1         52.243498          5.634323                  NL1  eredivisie
# 2         52.243498          5.634323                  NL1  eredivisie
# 3         52.243498          5.634323                  NL1  eredivisie
# 4         52.243498          5.634323                  NL1  eredivisie
#
#   confederation                                                url
# 0        europa  https://www.transfermarkt.co.uk/eredivisie/sta...
# 1        europa  https://www.transfermarkt.co.uk/eredivisie/sta...
# 2        europa  https://www.transfermarkt.co.uk/eredivisie/sta...
# 3        europa  https://www.transfermarkt.co.uk/eredivisie/sta...
# 4        europa  https://www.transfermarkt.co.uk/eredivisie/sta...
#
# [5 rows x 54 columns]

# %%
toptierplayers['date'] = pd.to_datetime(toptierplayers['date'], errors='coerce')

# %%
toptierplayers['Year']= toptierplayers['date'].dt.year
grouped_multiple = toptierplayers.groupby(['player_id', 'Year']).agg({'market_value': ['mean']})
grouped_multiple.columns = ['market_value_mean']
grouped_multiple['market_value_mean']= grouped_multiple['market_value_mean'].astype(int)
players_avg_value_per_year = grouped_multiple.reset_index()
players_avg_value_per_year.head()
# Out:
#    player_id  Year  market_value_mean
# 0       2857  2004             100000
# 1       2857  2005             516666
# 2       2857  2006             900000
# 3       2857  2007            1000000
# 4       2857  2008            1266666

# %%
list=[x for x in range(2003, 2022+1)]
WorldCupList = {'World Cup': ['2006','2006','2006','2006', '2010', '2010','2010','2010','2014','2014','2014','2014','2018','2018','2018','2018','2022','2022','2022','2022'], 'Year': list}
WorldCupYears = pd.DataFrame(WorldCupList)

# %%
players_avg_value_per_wc = pd.merge(players_avg_value_per_year, WorldCupYears, left_on='Year', right_on='Year')
players_avg_value_per_wc = players_avg_value_per_wc.groupby(['player_id', 'World Cup']).agg({'market_value_mean': ['mean', 'min', 'max']})
players_avg_value_per_wc.columns = ['market_value_mean', 'market_value_min', 'market_value_max']
players_avg_value_per_wc['market_value_mean']= players_avg_value_per_wc['market_value_mean'].astype(int)
players_avg_value_per_wc = players_avg_value_per_wc.reset_index()

# %%
players_avg_value_per_wc = players_avg_value_per_wc.groupby(['player_id', 'World Cup']).agg({'market_value_mean': ['mean', 'min', 'max']})
players_avg_value_per_wc.columns = ['market_value_mean', 'market_value_min', 'market_value_max']
players_avg_value_per_wc = players_avg_value_per_wc.reset_index()

# %%
players_avg_value_per_wc
# Out:
#        player_id World Cup  market_value_mean  market_value_min  \
# 0           2857      2006           505555.0            505555
# 1           2857      2010          1129166.0           1129166
# 2           2857      2014           708333.0            708333
# 3           2857      2018           681250.0            681250
# 4           2857      2022           477083.0            477083
# ...          ...       ...                ...               ...
# 14697    1048097      2022            50000.0             50000
# 14698    1048954      2022            50000.0             50000
# 14699    1050249      2022            75000.0             75000
# 14700    1050852      2022            50000.0             50000
# 14701    1056907      2022           100000.0            100000
#
#        market_value_max
# 0                505555
# 1               1129166
# 2                708333
# 3                681250
# 4                477083
# ...                 ...
# 14697             50000
# 14698             50000
# 14699             75000
# 14700             50000
# 14701            100000
#
# [14702 rows x 5 columns]

# %%
toptierplayers_per_wc = pd.merge(toptierplayers,players_avg_value_per_wc,on = 'player_id')

# %%
toptierplayers_per_wc.columns
# Out:
# Index(['player_id', 'pretty_name_x', 'club_id', 'club_pretty_name',
#        'current_club_id_x', 'country_of_citizenship', 'country_of_birth',
#        'date_of_birth', 'position', 'sub_position', 'name_x', 'foot',
#        'height_in_cm', 'market_value_in_gbp', 'highest_market_value_in_gbp',
#        'agent_name', 'contract_expiration_date', 'domestic_competition_id_x',
#        'club_name', 'image_url', 'last_season', 'url_x', 'date', 'datetime',
#        'dateweek', 'current_club_id_y', 'market_value',
#        'player_club_domestic_competition_id', 'name_y', 'pretty_name_y',
#        'domestic_competition_id_y', 'total_market_value', 'squad_size',
#        'average_age', 'foreigners_number', 'foreigners_percentage',
#        'national_team_players', 'stadium_name', 'stadium_seats',
#        'net_transfer_record', 'coach_name', 'url_y', 'competition_id',
#        'pretty_name', 'type', 'sub_type', 'country_id', 'country_name',
#        'country_latitude', 'country_longitude', 'domestic_league_code', 'name',
#        'confederation', 'url', 'Year', 'World Cup', 'market_value_mean',
#        'market_value_min', 'market_value_max'],
#       dtype='object')

# %%
WC_2022_teams = ['Qatar', 'Germany', 'Denmark', 'Brazil', 'France', 'Belgium', 'Croatia', 'Spain', 'Serbia', 'England', 'Switzerland', 'Netherlands', 'Argentina', 'IR Iran', 'Korea Republic', 'Japan', 'Saudi Arabia', 'Ecuador', 'Uruguay', 'Canada', 'Ghana', 'Senegal', 'Portugal', 'Poland', 'Tunisia', 'Morocco', 'Cameroon', 'United States', 'Mexico', 'Wales', 'Australia', 'Costa Rica']

# %%
print(toptierplayers_per_wc["country_of_citizenship"].unique())
print(TopTier_2022_WC_Eligble_Players["country_of_citizenship"].unique())
# Out:
# ['Brazil' 'Mexico' 'Iran' 'Sweden' 'Netherlands' 'Morocco' 'Argentina'
#  'Poland' 'Turkey' 'Norway' 'Slovakia' 'Austria' 'Denmark' 'Peru' 'Israel'
#  'Germany' 'Portugal' 'Italy' 'Serbia' 'Ghana' 'Nigeria' 'Belgium'
#  'United States' 'England' "Cote d'Ivoire" 'France' 'Greece' 'Curacao'
#  'Spain' 'Suriname' 'Comoros' 'Japan' 'DR Congo' 'Tunisia' 'Luxembourg'
#  'Iceland' 'Gabon' 'Latvia' 'Switzerland' 'Guinea' 'Sierra Leone' 'Haiti'
#  'Croatia' 'Finland' 'Estonia' 'Costa Rica' 'Czech Republic' 'Algeria'
#  'Hungary' 'Kosovo' 'Armenia' 'Cape Verde' 'Madagascar' 'Colombia' 'Chile'
#  'Honduras' 'Uruguay' 'Paraguay' 'Senegal' 'Australia' 'Zimbabwe'
#  'Korea, South' 'Ecuador' 'Martinique' 'Mali' 'Guinea-Bissau' 'Albania'
#  'Central African Republic' 'Mozambique' 'Montenegro' 'Slovenia'
#  'Venezuela' 'Dominican Republic' 'Ukraine' 'North Macedonia' 'Togo'
#  'Guadeloupe' 'Georgia' 'Belarus' 'Congo' 'Bosnia-Herzegovina' 'Cameroon'
#  'Moldova' 'Azerbaijan' 'Kazakhstan' 'Canada' 'Jamaica' 'Burkina Faso'
#  'New Zealand' 'Zambia' 'Uganda' 'The Gambia' 'Faroe Islands' 'Thailand'
#  'South Africa' 'Iraq' 'Philippines' 'Scotland' 'Bulgaria' 'Russia'
#  'Ireland' 'Egypt' 'Angola' 'Romania' 'Uzbekistan' 'Burundi' 'Syria'
#  'Lithuania' 'Bolivia' 'Mauritania' 'Indonesia' 'Cyprus'
#  'Trinidad and Tobago' 'Wales' 'French Guiana' 'Benin' 'Northern Ireland'
#  'Grenada' 'Montserrat' 'Equatorial Guinea' 'Southern Sudan' 'Malta'
#  'Kenya' 'Palästina' 'Panama' 'Libya' 'Tanzania' 'Chad' 'Jordan'
#  'Malaysia']
# ['France' 'Argentina' 'Brazil' 'England' 'Belgium' 'Senegal' 'Portugal'
#  'Germany' 'Poland' 'Netherlands' 'Spain' 'Serbia' 'Uruguay' 'Morocco'
#  'Canada' 'Denmark' 'Croatia' 'Ghana' 'Mexico' 'Wales' 'Switzerland'
#  'Cameroon' 'Japan' 'Costa Rica' 'Ecuador' 'Tunisia' 'Australia']

# %%
TopTier_2022_WC_Eligble_Players = toptierplayers_per_wc[toptierplayers_per_wc.country_of_citizenship.isin(WC_2022_teams)]

# %%
TopTier_2022_WC_Eligble_Players =TopTier_2022_WC_Eligble_Players[['World Cup','player_id','pretty_name_x','country_of_citizenship','position','sub_position','date_of_birth','name','market_value_mean','market_value_min','market_value_max']]

# %%
TopTier_2022_WC_Eligble_Players.head()
# Out:
#   World Cup  player_id pretty_name_x country_of_citizenship position  \
# 0      2022     519731        Danilo                 Brazil   Attack
# 1      2022     519731        Danilo                 Brazil   Attack
# 2      2022     519731        Danilo                 Brazil   Attack
# 3      2022     519731        Danilo                 Brazil   Attack
# 4      2022     519731        Danilo                 Brazil   Attack
#
#      sub_position date_of_birth        name  market_value_mean  \
# 0  Centre-Forward    1999-04-07  eredivisie          2824999.0
# 1  Centre-Forward    1999-04-07  eredivisie          2824999.0
# 2  Centre-Forward    1999-04-07  eredivisie          2824999.0
# 3  Centre-Forward    1999-04-07  eredivisie          2824999.0
# 4  Centre-Forward    1999-04-07  eredivisie          2824999.0
#
#    market_value_min  market_value_max
# 0           2824999           2824999
# 1           2824999           2824999
# 2           2824999           2824999
# 3           2824999           2824999
# 4           2824999           2824999

# %%
TopTier_2022_WC_Eligble_Players = TopTier_2022_WC_Eligble_Players.drop_duplicates()

# %%
TopTier_2022_WC_Eligble_Players = TopTier_2022_WC_Eligble_Players.sort_values(by='market_value_mean',ascending=False)

# %%
TopTier_2022_WC_Eligble_Players.head(20)
# Out:
#        World Cup  player_id           pretty_name_x country_of_citizenship  \
# 172148      2022     342229           Kylian Mbappe                 France
# 172194      2018      28003            Lionel Messi              Argentina
# 172393      2018      68290                  Neymar                 Brazil
# 186484      2022     132098              Harry Kane                England
# 172394      2022      68290                  Neymar                 Brazil
# 172193      2014      28003            Lionel Messi              Argentina
# 203871      2022      88755         Kevin De Bruyne                Belgium
# 197572      2022     134425         Raheem Sterling                England
# 91354       2022     200512              Sadio Mane                Senegal
# 204250      2022     401173            Jadon Sancho                England
# 172195      2022      28003            Lionel Messi              Argentina
# 192054      2022     314353  Trent Alexander Arnold                England
# 40341       2018      50202             Eden Hazard                Belgium
# 222348      2022      96341           Romelu Lukaku                Belgium
# 202476      2022     241641          Bernardo Silva               Portugal
# 90470       2022     161056          Joshua Kimmich                Germany
# 30476       2018     125781       Antoine Griezmann                 France
# 197309      2022     309400             Kai Havertz                Germany
# 203870      2018      88755         Kevin De Bruyne                Belgium
# 91228       2022     192565              Leroy Sane                Germany
#
#         position        sub_position date_of_birth            name  \
# 172148    Attack      Centre-Forward    1998-12-20         ligue-1
# 172194    Attack        Right Winger    1987-06-24         ligue-1
# 172393    Attack         Left Winger    1992-02-05         ligue-1
# 186484    Attack      Centre-Forward    1993-07-28  premier-league
# 172394    Attack         Left Winger    1992-02-05         ligue-1
# 172193    Attack        Right Winger    1987-06-24         ligue-1
# 203871    Attack  Attacking Midfield    1991-06-28  premier-league
# 197572    Attack         Left Winger    1994-12-08  premier-league
# 91354     Attack         Left Winger    1992-04-10      bundesliga
# 204250    Attack         Left Winger    2000-03-25  premier-league
# 172195    Attack        Right Winger    1987-06-24         ligue-1
# 192054  Defender          Right-Back    1998-10-07  premier-league
# 40341     Attack         Left Winger    1991-01-07          laliga
# 222348    Attack      Centre-Forward    1993-05-13         serie-a
# 202476    Attack  Attacking Midfield    1994-08-10  premier-league
# 90470   Midfield  Defensive Midfield    1995-02-08      bundesliga
# 30476     Attack      Second Striker    1991-03-21          laliga
# 197309    Attack  Attacking Midfield    1999-06-11  premier-league
# 203870    Attack  Attacking Midfield    1991-06-28  premier-league
# 91228     Attack         Left Winger    1996-01-11      bundesliga
#
#         market_value_mean  market_value_min  market_value_max
# 172148        175000000.0         175000000         175000000
# 172194        133333333.0         133333333         133333333
# 172393        120833333.0         120833333         120833333
# 186484        118333333.0         118333333         118333333
# 172394        118250000.0         118250000         118250000
# 172193        112500000.0         112500000         112500000
# 203871        109791666.0         109791666         109791666
# 197572        108416666.0         108416666         108416666
# 91354          97499999.0          97499999          97499999
# 204250         95270833.0          95270833          95270833
# 172195         93583333.0          93583333          93583333
# 192054         86583333.0          86583333          86583333
# 40341          82541666.0          82541666          82541666
# 222348         81750000.0          81750000          81750000
# 202476         80416666.0          80416666          80416666
# 90470          79499999.0          79499999          79499999
# 30476          79333333.0          79333333          79333333
# 197309         77750000.0          77750000          77750000
# 203870         76749999.0          76749999          76749999
# 91228          76250000.0          76250000          76250000

# %%
TopTier_2022_WC_Eligble_Players[TopTier_2022_WC_Eligble_Players['player_id'].isin([50202])]
# Out:
#       World Cup  player_id pretty_name_x country_of_citizenship position  \
# 40341      2018      50202   Eden Hazard                Belgium   Attack
# 40342      2022      50202   Eden Hazard                Belgium   Attack
# 40340      2014      50202   Eden Hazard                Belgium   Attack
# 40339      2010      50202   Eden Hazard                Belgium   Attack
#
#       sub_position date_of_birth    name  market_value_mean  market_value_min  \
# 40341  Left Winger    1991-01-07  laliga         82541666.0          82541666
# 40342  Left Winger    1991-01-07  laliga         65358333.0          65358333
# 40340  Left Winger    1991-01-07  laliga         35791666.0          35791666
# 40339  Left Winger    1991-01-07  laliga          6700000.0           6700000
#
#        market_value_max
# 40341          82541666
# 40342          65358333
# 40340          35791666
# 40339           6700000

# %% [markdown]
# ## EA Sports FIFA Ratings

# %%
od.download("https://www.kaggle.com/datasets/sanjeetsinghnaik/fifa-23-players-dataset")
# Out:
# Skipping, found downloaded files in "./fifa-23-players-dataset" (use force=True to force download)

# %%
fifa23data = (r'/Users/mallon/Desktop/UCD Data Analytics for Finance/fifa-23-players-dataset/Fifa 23 Players Data.csv')
fifa23= pd.read_csv(fifa23data)

# %%
print(fifa23.columns)
# Out:
# Index(['Known As', 'Full Name', 'Overall', 'Potential', 'Value(in Euro)',
#        'Positions Played', 'Best Position', 'Nationality', 'Image Link', 'Age',
#        'Height(in cm)', 'Weight(in kg)', 'TotalStats', 'BaseStats',
#        'Club Name', 'Wage(in Euro)', 'Release Clause', 'Club Position',
#        'Contract Until', 'Club Jersey Number', 'Joined On', 'On Loan',
#        'Preferred Foot', 'Weak Foot Rating', 'Skill Moves',
#        'International Reputation', 'National Team Name',
#        'National Team Image Link', 'National Team Position',
#        'National Team Jersey Number', 'Attacking Work Rate',
#        'Defensive Work Rate', 'Pace Total', 'Shooting Total', 'Passing Total',
#        'Dribbling Total', 'Defending Total', 'Physicality Total', 'Crossing',
#        'Finishing', 'Heading Accuracy', 'Short Passing', 'Volleys',
#        'Dribbling', 'Curve', 'Freekick Accuracy', 'LongPassing', 'BallControl',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
#        'Composure', 'Marking', 'Standing Tackle', 'Sliding Tackle',
#        'Goalkeeper Diving', 'Goalkeeper Handling', ' GoalkeeperKicking',
#        'Goalkeeper Positioning', 'Goalkeeper Reflexes', 'ST Rating',
#        'LW Rating', 'LF Rating', 'CF Rating', 'RF Rating', 'RW Rating',
#        'CAM Rating', 'LM Rating', 'CM Rating', 'RM Rating', 'LWB Rating',
#        'CDM Rating', 'RWB Rating', 'LB Rating', 'CB Rating', 'RB Rating',
#        'GK Rating'],
#       dtype='object')

# %%
fifa23 = fifa23[['Full Name', 'Overall', 'Potential', 'Value(in Euro)',
       'Positions Played', 'Best Position', 'Nationality', 'Image Link', 'Age',
       'Height(in cm)', 'TotalStats', 
       'Club Name', 'Wage(in Euro)', 'Release Clause', 'Club Position', 'Club Jersey Number',
       'Skill Moves','International Reputation', 
        'National Team Name','National Team Image Link', 'National Team Position',
       'National Team Jersey Number','Finishing','Short Passing', 'Sprint Speed', 'Stamina', 'Strength', 'Penalties']]

# %%
fifa23.head(5)
# Out:
#             Full Name  Overall  Potential  Value(in Euro) Positions Played  \
# 0        Lionel Messi       91         91        54000000               RW
# 1       Karim Benzema       91         91        64000000            CF,ST
# 2  Robert Lewandowski       91         91        84000000               ST
# 3     Kevin De Bruyne       91         91       107500000           CM,CAM
# 4       Kylian Mbappé       91         95       190500000            ST,LW
#
#   Best Position Nationality                                        Image Link  \
# 0           CAM   Argentina  https://cdn.sofifa.net/players/158/023/23_60.png
# 1            CF      France  https://cdn.sofifa.net/players/165/153/23_60.png
# 2            ST      Poland  https://cdn.sofifa.net/players/188/545/23_60.png
# 3            CM     Belgium  https://cdn.sofifa.net/players/192/985/23_60.png
# 4            ST      France  https://cdn.sofifa.net/players/231/747/23_60.png
#
#    Age  Height(in cm)  ...  National Team Name  \
# 0   35            169  ...           Argentina
# 1   34            185  ...              France
# 2   33            185  ...              Poland
# 3   31            181  ...             Belgium
# 4   23            182  ...              France
#
#               National Team Image Link  National Team Position  \
# 0  https://cdn.sofifa.net/flags/ar.png                      RW
# 1  https://cdn.sofifa.net/flags/fr.png                      ST
# 2  https://cdn.sofifa.net/flags/pl.png                      ST
# 3  https://cdn.sofifa.net/flags/be.png                      RF
# 4  https://cdn.sofifa.net/flags/fr.png                      ST
#
#    National Team Jersey Number Finishing Short Passing  Sprint Speed  Stamina  \
# 0                           10        90            91            76       70
# 1                           19        92            89            80       82
# 2                            9        94            84            75       76
# 3                            7        85            93            73       88
# 4                           10        93            85            97       87
#
#   Strength Penalties
# 0       68        75
# 1       82        84
# 2       87        90
# 3       74        83
# 4       76        80
#
# [5 rows x 28 columns]

# %%
fifa23['Full Name']= fifa23['Full Name'].astype(str)
cols = ['Full Name']
fifa23[cols] = fifa23[cols].apply(lambda x: x.str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8'))

# %%
fifa23transfermarkt = pd.merge(left = fifa23, right = TopTier_2022_WC_Eligble_Players, how = 'inner', left_on='Full Name', right_on='pretty_name_x' )

# %% [markdown]
# ## Player Ratings Based on Transfer Value

# %%
fifa23transfermarkt['rank'] = fifa23transfermarkt['market_value_mean'].rank(ascending=False)

# %%
fifa23transfermarkt['rank']= fifa23transfermarkt['rank'].astype(int)

# %%
fifa23transfermarkt = fifa23transfermarkt.sort_values(by='rank',ascending=True)
fifa23transfermarkt.head(10)
# Out:
#            Full Name  Overall  Potential  Value(in Euro) Positions Played  \
# 18     Kylian Mbappe       91         95       190500000            ST,LW
# 0       Lionel Messi       91         91        54000000               RW
# 29        Harry Kane       89         89       105500000               ST
# 1       Lionel Messi       91         91        54000000               RW
# 14   Kevin De Bruyne       91         91       107500000           CM,CAM
# 77   Raheem Sterling       86         86        72500000            LW,RW
# 32        Sadio Mane       89         89        99500000            LM,CF
# 239     Jadon Sancho       84         88        61500000         LW,RW,LM
# 2       Lionel Messi       91         91        54000000               RW
# 203      Eden Hazard       84         84        35000000               LW
#
#     Best Position Nationality  \
# 18             ST      France
# 0             CAM   Argentina
# 29             ST     England
# 1             CAM   Argentina
# 14             CM     Belgium
# 77             LW     England
# 32             LM     Senegal
# 239           CAM     England
# 2             CAM   Argentina
# 203            LW     Belgium
#
#                                            Image Link  Age  Height(in cm)  \
# 18   https://cdn.sofifa.net/players/231/747/23_60.png   23            182
# 0    https://cdn.sofifa.net/players/158/023/23_60.png   35            169
# 29   https://cdn.sofifa.net/players/202/126/23_60.png   28            188
# 1    https://cdn.sofifa.net/players/158/023/23_60.png   35            169
# 14   https://cdn.sofifa.net/players/192/985/23_60.png   31            181
# 77   https://cdn.sofifa.net/players/202/652/23_60.png   27            170
# 32   https://cdn.sofifa.net/players/208/722/23_60.png   30            174
# 239  https://cdn.sofifa.net/players/233/049/23_60.png   22            180
# 2    https://cdn.sofifa.net/players/158/023/23_60.png   35            169
# 203  https://cdn.sofifa.net/players/183/277/23_60.png   31            175
#
#      ...    pretty_name_x country_of_citizenship  position  \
# 18   ...    Kylian Mbappe                 France    Attack
# 0    ...     Lionel Messi              Argentina    Attack
# 29   ...       Harry Kane                England    Attack
# 1    ...     Lionel Messi              Argentina    Attack
# 14   ...  Kevin De Bruyne                Belgium    Attack
# 77   ...  Raheem Sterling                England    Attack
# 32   ...       Sadio Mane                Senegal    Attack
# 239  ...     Jadon Sancho                England    Attack
# 2    ...     Lionel Messi              Argentina    Attack
# 203  ...      Eden Hazard                Belgium    Attack
#
#            sub_position date_of_birth            name  market_value_mean  \
# 18       Centre-Forward    1998-12-20         ligue-1        175000000.0
# 0          Right Winger    1987-06-24         ligue-1        133333333.0
# 29       Centre-Forward    1993-07-28  premier-league        118333333.0
# 1          Right Winger    1987-06-24         ligue-1        112500000.0
# 14   Attacking Midfield    1991-06-28  premier-league        109791666.0
# 77          Left Winger    1994-12-08  premier-league        108416666.0
# 32          Left Winger    1992-04-10      bundesliga         97499999.0
# 239         Left Winger    2000-03-25  premier-league         95270833.0
# 2          Right Winger    1987-06-24         ligue-1         93583333.0
# 203         Left Winger    1991-01-07          laliga         82541666.0
#
#      market_value_min market_value_max rank
# 18          175000000        175000000    1
# 0           133333333        133333333    2
# 29          118333333        118333333    3
# 1           112500000        112500000    4
# 14          109791666        109791666    5
# 77          108416666        108416666    6
# 32           97499999         97499999    7
# 239          95270833         95270833    8
# 2            93583333         93583333    9
# 203          82541666         82541666   10
#
# [10 rows x 40 columns]

# %%
print(fifa23transfermarkt.columns)
# Out:
# Index(['Full Name', 'Overall', 'Potential', 'Value(in Euro)',
#        'Positions Played', 'Best Position', 'Nationality', 'Image Link', 'Age',
#        'Height(in cm)', 'TotalStats', 'Club Name', 'Wage(in Euro)',
#        'Release Clause', 'Club Position', 'Club Jersey Number', 'Skill Moves',
#        'International Reputation', 'National Team Name',
#        'National Team Image Link', 'National Team Position',
#        'National Team Jersey Number', 'Finishing', 'Short Passing',
#        'Sprint Speed', 'Stamina', 'Strength', 'Penalties', 'World Cup',
#        'player_id', 'pretty_name_x', 'country_of_citizenship', 'position',
#        'sub_position', 'date_of_birth', 'name', 'market_value_mean',
#        'market_value_min', 'market_value_max', 'rank'],
#       dtype='object')

# %%
fifa23transfermarkt2022WC = fifa23transfermarkt[fifa23transfermarkt['World Cup']=='2022']

# %% [markdown]
# ##### Adding GoalKeepers to the Defence Grouping

# %%
fifa23transfermarkt2022WC["position"] = fifa23transfermarkt2022WC["position"].replace("Goalkeeper", "Defender")
# Out:
# /var/folders/2d/6361wtyx7h51kz0b56dmjd_80000gn/T/ipykernel_1817/2542873994.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fifa23transfermarkt2022WC["position"] = fifa23transfermarkt2022WC["position"].replace("Goalkeeper", "Defender")

# %% [markdown]
# #### Splitting every country into their own DataFrame

# %%
unique_countries = fifa23transfermarkt2022WC['country_of_citizenship'].unique()
unique_positions = fifa23transfermarkt2022WC['position'].unique()

# %%
print(unique_countries)
print(unique_positions)
# Out:
# ['France' 'England' 'Belgium' 'Senegal' 'Argentina' 'Germany' 'Uruguay'
#  'Poland' 'Spain' 'Morocco' 'Canada' 'Denmark' 'Croatia' 'Ghana'
#  'Netherlands' 'Mexico' 'Switzerland' 'Portugal' 'Cameroon' 'Wales'
#  'Japan' 'Serbia' 'Ecuador' 'Tunisia' 'Costa Rica' 'Australia' 'Brazil']
# ['Attack' 'Midfield' 'Defender']

# %%
fifa23transfermarkt2022WC
# Out:
#             Full Name  Overall  Potential  Value(in Euro) Positions Played  \
# 18      Kylian Mbappe       91         95       190500000            ST,LW
# 29         Harry Kane       89         89       105500000               ST
# 14    Kevin De Bruyne       91         91       107500000           CM,CAM
# 77    Raheem Sterling       86         86        72500000            LW,RW
# 32         Sadio Mane       89         89        99500000            LM,CF
# ...               ...      ...        ...             ...              ...
# 4806   Bryant Nieling       62         74          875000               CB
# 5094    Brett Minnema       56         67          275000               GK
# 5095        Max Wolfs       56         66          275000               GK
# 5006     Guus Gertsen       59         72          500000            CB,RB
# 5005     Joey Kesting       59         68          450000               GK
#
#      Best Position  Nationality  \
# 18              ST       France
# 29              ST      England
# 14              CM      Belgium
# 77              LW      England
# 32              LM      Senegal
# ...            ...          ...
# 4806            CB  Netherlands
# 5094            GK  Netherlands
# 5095            GK  Netherlands
# 5006            CB  Netherlands
# 5005            GK  Netherlands
#
#                                             Image Link  Age  Height(in cm)  \
# 18    https://cdn.sofifa.net/players/231/747/23_60.png   23            182
# 29    https://cdn.sofifa.net/players/202/126/23_60.png   28            188
# 14    https://cdn.sofifa.net/players/192/985/23_60.png   31            181
# 77    https://cdn.sofifa.net/players/202/652/23_60.png   27            170
# 32    https://cdn.sofifa.net/players/208/722/23_60.png   30            174
# ...                                                ...  ...            ...
# 4806  https://cdn.sofifa.net/players/271/215/23_60.png   19            193
# 5094  https://cdn.sofifa.net/players/262/266/23_60.png   20            192
# 5095  https://cdn.sofifa.net/players/271/313/23_60.png   20            190
# 5006  https://cdn.sofifa.net/players/262/601/23_60.png   19            189
# 5005  https://cdn.sofifa.net/players/265/745/23_60.png   21            190
#
#       ...  country_of_citizenship  position        sub_position  \
# 18    ...                  France    Attack      Centre-Forward
# 29    ...                 England    Attack      Centre-Forward
# 14    ...                 Belgium    Attack  Attacking Midfield
# 77    ...                 England    Attack         Left Winger
# 32    ...                 Senegal    Attack         Left Winger
# ...   ...                     ...       ...                 ...
# 4806  ...             Netherlands  Defender         Centre-Back
# 5094  ...             Netherlands  Defender                 NaN
# 5095  ...             Netherlands  Defender                 NaN
# 5006  ...             Netherlands  Defender         Centre-Back
# 5005  ...             Netherlands  Defender                 NaN
#
#       date_of_birth            name market_value_mean  market_value_min  \
# 18       1998-12-20         ligue-1       175000000.0         175000000
# 29       1993-07-28  premier-league       118333333.0         118333333
# 14       1991-06-28  premier-league       109791666.0         109791666
# 77       1994-12-08  premier-league       108416666.0         108416666
# 32       1992-04-10      bundesliga        97499999.0          97499999
# ...             ...             ...               ...               ...
# 4806     2002-10-31      eredivisie           25000.0             25000
# 5094     2002-01-06      eredivisie           25000.0             25000
# 5095     2002-05-04      eredivisie           25000.0             25000
# 5006     2003-04-16      eredivisie           25000.0             25000
# 5005     2001-03-07      eredivisie           25000.0             25000
#
#       market_value_max  rank column_name
# 18           175000000     1      Attack
# 29           118333333     3      Attack
# 14           109791666     5      Attack
# 77           108416666     6      Attack
# 32            97499999     7      Attack
# ...                ...   ...         ...
# 4806             25000  5112    Defender
# 5094             25000  5112  Goalkeeper
# 5095             25000  5112  Goalkeeper
# 5006             25000  5112    Defender
# 5005             25000  5112  Goalkeeper
#
# [2293 rows x 41 columns]

# %%
# creating a dicttionary of each team split into seperate dataframes
WorldCupTeams = {}


# Split the DataFrame into multiple DataFrames based on the unique values

for value1 in unique_countries:
  for value2 in unique_positions:
    value_df = fifa23transfermarkt2022WC[(fifa23transfermarkt2022WC['country_of_citizenship'] == value1) & (fifa23transfermarkt2022WC['position'] == value2)]
    WorldCupTeams[(value1, value2)] = value_df

#sets a dataframe for each variation of country and each position

for key, value in WorldCupTeams.items():
  # Create a DataFrame with the same name as the key
  globals()["_".join(key)] = pd.DataFrame(value)

# %%
Belgium_Defender.head(5)
# Out:
#              Full Name  Overall  Potential  Value(in Euro) Positions Played  \
# 20    Thibaut Courtois       90         91        90000000               GK
# 941   Timothy Castagne       78         80        16000000            RB,LB
# 375  Toby Alderweireld       82         82        14500000               CB
# 962     Thomas Meunier       78         78        12000000            RB,RM
# 191      Koen Casteels       84         85        31500000               GK
#
#     Best Position Nationality  \
# 20             GK     Belgium
# 941           RWB     Belgium
# 375            CB     Belgium
# 962            RB     Belgium
# 191            GK     Belgium
#
#                                            Image Link  Age  Height(in cm)  \
# 20   https://cdn.sofifa.net/players/192/119/23_60.png   30            199
# 941  https://cdn.sofifa.net/players/222/501/23_60.png   26            185
# 375  https://cdn.sofifa.net/players/184/087/23_60.png   33            186
# 962  https://cdn.sofifa.net/players/202/371/23_60.png   30            191
# 191  https://cdn.sofifa.net/players/192/984/23_60.png   30            197
#
#      ...  country_of_citizenship  position  sub_position  date_of_birth  \
# 20   ...                 Belgium  Defender           NaN     1992-05-11
# 941  ...                 Belgium  Defender    Right-Back     1995-12-05
# 375  ...                 Belgium  Defender   Centre-Back     1989-03-02
# 962  ...                 Belgium  Defender    Right-Back     1991-09-12
# 191  ...                 Belgium  Defender           NaN     1992-06-25
#
#                    name market_value_mean  market_value_min  market_value_max  \
# 20               laliga        60604166.0          60604166          60604166
# 941      premier-league        22499999.0          22499999          22499999
# 375  jupiler-pro-league        20041666.0          20041666          20041666
# 962          bundesliga        17562500.0          17562500          17562500
# 191          bundesliga        11500000.0          11500000          11500000
#
#     rank column_name
# 20    34  Goalkeeper
# 941  259    Defender
# 375  291    Defender
# 962  342    Defender
# 191  593  Goalkeeper
#
# [5 rows x 41 columns]

# %%
def play_game(team1, team2, team1_rating, team2_rating):
  # Determine the probability that team1 wins based on the ratings
  p1 = 1.0 / (1.0 + 10.0**((team2_rating - team1_rating) / 400.0))

  # Use the probability to determine the outcome of the game
  if random.random() <= p1:
    # Team 1 wins
    return team1, p1 *100
  else:
    # Team 2 wins
    return team2

# %%
print(play_game("Belgium", "Brazil", Belgium["market_value_mean"].mean(), Brazil["market_value_mean"].mean()))
print(play_game("Belgium", "Brazil", Belgium["Age"].mean(), Brazil["Age"].mean()))
# Out:
# ('Belgium', 100.0)
# ('Belgium', 49.69680689402655)

# %%
print(Belgium["market_value_mean"].mean())
print(Brazil["market_value_mean"].mean())
# Out:
# 4445412.232931727
# 2162499.6

# %%
print(Belgium["Age"].mean())
print(Brazil["Age"].mean())
# Out:
# 24.29317269076305
# 26.4

# %%
def play_game(team1, team2, team1_def, team1_mid, team1_att, team2_def, team2_mid, team2_att):
  # Calculate the overall rating for each team's attack and midfield
  team1_att_mid_rating = (team1_att + team1_mid) / 2
  team2_att_mid_rating = (team2_att + team2_mid) / 2

  # Calculate the probability that team1's attack and midfield win against team2's defense
  p1 = 1.0 / (1.0 + 10.0**((team2_def - team1_att_mid_rating) / 400.0))

  # Use the probability to determine the outcome of the game
  if random.random() <= p1:
    # Team 1's attack and midfield win
    # Now we need to determine the outcome of the game based on the ratings of the two teams' midfields
    p1 = 1.0 / (1.0 + 10.0**((team2_mid - team1_mid) / 400.0))
    if random.random() <= p1:
      # Team 1 wins
      return team1
    else:
      # Team 2 wins
      return team2
  else:
    # Team 2's defense wins
    # Now we need to determine the outcome of the game based on the ratings of the two teams' midfields
    p1 = 1.0 / (1.0 + 10.0**((team2_mid - team1_mid) / 400.0))
    if random.random() <= p1:
      # Team 2 wins
      return team2
    else:
      # Team 1 wins
      return team1

# %%
England_Attack.head(15)
# Out:
#             Full Name  Overall  Potential  Value(in Euro) Positions Played  \
# 29         Harry Kane       89         89       105500000               ST
# 77    Raheem Sterling       86         86        72500000            LW,RW
# 239      Jadon Sancho       84         88        61500000         LW,RW,LM
# 436   Marcus Rashford       81         85        37000000            LW,ST
# 164     Jack Grealish       84         84        46000000        LW,LM,CAM
# 237       Mason Mount       84         87        57500000           CAM,RW
# 292    James Maddison       82         84        38000000           CAM,RM
# 1082        Dele Alli       77         80        14000000           CAM,CM
# 330     Tammy Abraham       82         85        42000000               ST
# 624      Jarrod Bowen       80         83        28000000            RM,ST
# 1064       Ivan Toney       77         79        13000000               ST
# 939     Ollie Watkins       78         81        18500000            ST,LW
# 787     Callum Wilson       79         79        17000000               ST
# 910     Jesse Lingard       78         78        14000000              CAM
# 791        Danny Ings       79         79        17500000               ST
#
#      Best Position Nationality  \
# 29              ST     England
# 77              LW     England
# 239            CAM     England
# 436             ST     England
# 164             LW     England
# 237            CAM     England
# 292            CAM     England
# 1082            ST     England
# 330             ST     England
# 624             LM     England
# 1064            ST     England
# 939             ST     England
# 787             ST     England
# 910            CAM     England
# 791             ST     England
#
#                                             Image Link  Age  Height(in cm)  \
# 29    https://cdn.sofifa.net/players/202/126/23_60.png   28            188
# 77    https://cdn.sofifa.net/players/202/652/23_60.png   27            170
# 239   https://cdn.sofifa.net/players/233/049/23_60.png   22            180
# 436   https://cdn.sofifa.net/players/231/677/23_60.png   24            186
# 164   https://cdn.sofifa.net/players/206/517/23_60.png   26            180
# 237   https://cdn.sofifa.net/players/233/064/23_60.png   23            180
# 292   https://cdn.sofifa.net/players/220/697/23_60.png   25            175
# 1082  https://cdn.sofifa.net/players/211/117/23_60.png   26            188
# 330   https://cdn.sofifa.net/players/231/352/23_60.png   24            195
# 624   https://cdn.sofifa.net/players/224/371/23_60.png   25            175
# 1064  https://cdn.sofifa.net/players/212/228/23_60.png   26            187
# 939   https://cdn.sofifa.net/players/221/697/23_60.png   26            180
# 787   https://cdn.sofifa.net/players/196/978/23_60.png   30            180
# 910   https://cdn.sofifa.net/players/207/494/23_60.png   29            175
# 791   https://cdn.sofifa.net/players/195/859/23_60.png   29            178
#
#       ...  country_of_citizenship position        sub_position  date_of_birth  \
# 29    ...                 England   Attack      Centre-Forward     1993-07-28
# 77    ...                 England   Attack         Left Winger     1994-12-08
# 239   ...                 England   Attack         Left Winger     2000-03-25
# 436   ...                 England   Attack         Left Winger     1997-10-31
# 164   ...                 England   Attack         Left Winger     1995-09-10
# 237   ...                 England   Attack  Attacking Midfield     1999-01-10
# 292   ...                 England   Attack  Attacking Midfield     1996-11-23
# 1082  ...                 England   Attack  Attacking Midfield     1996-04-11
# 330   ...                 England   Attack      Centre-Forward     1997-10-02
# 624   ...                 England   Attack        Right Winger     1996-12-20
# 1064  ...                 England   Attack      Centre-Forward     1996-03-16
# 939   ...                 England   Attack      Centre-Forward     1995-12-30
# 787   ...                 England   Attack      Centre-Forward     1992-02-27
# 910   ...                 England   Attack  Attacking Midfield     1992-12-15
# 791   ...                 England   Attack      Centre-Forward     1992-07-23
#
#                 name market_value_mean  market_value_min  market_value_max  \
# 29    premier-league       118333333.0         118333333         118333333
# 77    premier-league       108416666.0         108416666         108416666
# 239   premier-league        95270833.0          95270833          95270833
# 436   premier-league        75333333.0          75333333          75333333
# 164   premier-league        54237500.0          54237500          54237500
# 237   premier-league        53312500.0          53312500          53312500
# 292   premier-league        51812499.0          51812499          51812499
# 1082       super-lig        48708333.0          48708333          48708333
# 330          serie-a        38645833.0          38645833          38645833
# 624   premier-league        26229166.0          26229166          26229166
# 1064  premier-league        23738888.0          23738888          23738888
# 939   premier-league        23708333.0          23708333          23708333
# 787   premier-league        23124999.0          23124999          23124999
# 910   premier-league        21718750.0          21718750          21718750
# 791   premier-league        19093750.0          19093750          19093750
#
#      rank column_name
# 29      3      Attack
# 77      6      Attack
# 239     8      Attack
# 436    17      Attack
# 164    47      Attack
# 237    52      Attack
# 292    53      Attack
# 1082   58      Attack
# 330    98      Attack
# 624   195      Attack
# 1064  240      Attack
# 939   241      Attack
# 787   250      Attack
# 910   273      Attack
# 791   314      Attack
#
# [15 rows x 41 columns]

# %%
def play_game(team1_def_rating,team1_mid_rating,team1_att_rating,team2_def_rating,team2_mid_rating,team2_att_rating):


  team1_rounds = 0
  team2_rounds = 0

  # Check if team 1's attack is greater than team 2's defense
  if (team1_att_rating["Overall"].mean() > team2_def_rating["Overall"].mean()):
    # Calculate the difference in ratings
    rating_diff = team1_att_rating["Overall"].mean() - team2_def_rating["Overall"].mean()
    # Calculate the probability of a normal distribution with a mean equal to the difference in ratings
    # and a standard deviation of 1
    probability = norm.cdf(rating_diff, 1)
    # Generate a random number between 0 and 1
    rand = random.random()
    # If the random number is less than the probability of winning, team 1 wins a round
    if rand < probability:
      team1_rounds += 1
    

  # Check if team 2's attack is greater than team 1's defense
  if (team2_att_rating["Overall"].mean() > team1_def_rating["Overall"].mean()):
    # Calculate the difference in ratings
    rating_diff = team2_att_rating["Overall"].mean() - team1_def_rating["Overall"].mean()
    # Calculate the probability of a normal distribution with a mean equal to the difference in ratings
    # and a standard deviation of 1
    probability = norm.cdf(rating_diff, 1)
    # Generate a random number between 0 and 1
    rand = random.random()
    # If the random number is less than the probability of winning, team 1 wins a round
    if rand < probability:
      team2_rounds += 1
    
    
 

   # Check if team 2's midfield is greater than team 1's midfield
  if (team2_mid_rating["Overall"].mean() > team1_mid_rating["Overall"].mean()):
    # Calculate the difference in ratings
    rating_diff = team2_mid_rating["Overall"].mean() - team1_mid_rating["Overall"].mean()
    # Calculate the probability of a normal distribution with a mean equal to the difference in ratings
    # and a standard deviation of 1
    probability = norm.cdf(rating_diff, 1)
    # Generate a random number between 0 and 1
    rand = random.random()
    # If the random number is less than the probability of winning, team 2 wins a round
    if rand < probability:
      team2_rounds += 1
    
    
    print(round(team1_att_rating["Overall"].mean(),2) , "Team1 Attack") 
    print(round(team1_mid_rating["Overall"].mean(),2) , "Team1 Midfield")
    print(round(team1_def_rating["Overall"].mean(),2) , "Team1 Defending")
    print(round(team2_def_rating["Overall"].mean(),2) , "Team2 Defending")
    print(round(team2_mid_rating["Overall"].mean(),2) , "Team2 Midfield") 
    print(round(team2_att_rating["Overall"].mean(),2) , "Team2 Attacking") 
    

  if team1_rounds > team2_rounds:
    return "Team 1 wins!"
  elif team1_rounds < team2_rounds:
    return "Team 2 wins!"
  else:
    return "It's a draw!"

# %%
play_game(Belgium_Defender,Belgium_Midfield,Belgium_Attack,England_Defender,England_Midfield,England_Attack)
# Out:
# 69.68 Team1 Attack
# 68.14 Team1 Midfield
# 67.18 Team1 Defending
# 71.18 Team2 Defending
# 73.28 Team2 Midfield
# 72.69 Team2 Attacking
# 'Team 2 wins!'

# %%
play_game(Belgium_Defender,Belgium_Midfield,Belgium_Attack,England_Defender,England_Midfield,England_Attack)
# Out:
# 69.68 Team1 Attack
# 68.14 Team1 Midfield
# 67.18 Team1 Defending
# 71.18 Team2 Defending
# 73.28 Team2 Midfield
# 72.69 Team2 Attacking
# 'Team 2 wins!'
