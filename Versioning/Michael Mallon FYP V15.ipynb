# %% [raw]
# import sys
# !{sys.executable} -m pip install opendatasets

# %%
    1. Data
        The project should use a real-world dataset and include a reference to thesource in the report - DONE
    2. Importing
        Import data from a flat file (.csv, .xls, xlsx, .txt, etc.) - DONE
        Retrieve data using online SQL, APIs, or web scraping - DONE - kaggle pull and FIFA ranking scrape
    3. Preparation
        Create pandas DataFrame - DONE
        Sorting, indexing, grouping - NO SORT NO INDEX READ INTO THESE
        Drop duplicates, replace missing values - NO DROP DUP NO REPLACE MISS
        Merge DataFrames - DONE
    4. Analysis
        Conditional statements, looping, groupby - NO COND OR LOOP DO THIS IN SQUAD FUNCTION, YES GROUPING
        Define a custom function to create reusable code - TO DO FOR MATCH FUNCTIONS
        Use NumPy functions - NO NUMPY
        Dictionary or Lists - LISTS USED FOR WC TEAMS
    5. Visualisation
        Generate at least two charts using Matplotlib or Seaborn - YES DESCRIBED BELOW, DO SOME ADD ANALYSIS ONES AT BEGINNING IE DIST (WC TEAMS AND NOT) ETC
    6. Insights
        Derive five valuable insights from the analysis - BEST TEAMS ARE HIGH VAL+LUES RATINGS STRENGTH ETC
        Justify your insights with reference to the charts or analysis _ USE GRAPHS
    7. Machine Learning
        Describe what kind of prediction you could perform in future using machine learning and/or deep learning. - INCLUDE MORE DTA IE OLD WORLD CUP EVEN CLUB MATCHES
        Would you use classification or regression methods? - NO TO LOOK INTO

# %%
## plan

Take each player:
    Group by Position:
        Weighted forumla that is normalised 70-100 between:
            World Cup Value - player value (average of four years)
            Current transfermarkt summised value
            Current fifa rating
            Potential Rating
        Get each players rating.
    Group by Nationality
        Take the best X players for each position (ie: 3 goalkeeper etc)
        Build a 25 man squad (look for players not included from lower clubs that have been ommited (added these back in seperatley) maybe come back and do fulls scope of players)
    Create a squad rating
        DEF rating
        MID rating
        ATT rating
        FIFA world ranking - web scrape
    Create function that will play each against eachother
        Play group stages loaded in
        Play round of 16
        Play round of 8
        Play semis
        Play final
            Form Increased if you win
                For each match:
                    Team rating will increase/remain/decrease per result (will need recalculated):
                    Win +2 per rating
                    Draw 0 per rating
                    Loss -1 per rating
Visuals of best team on average with:
    Team Averages:
        Strength
        Skills 
        Etc
    Best and Worst Team XI's: 
        (Copy FYP) - use the image links
        Overall
        Potential etc
    Best Players not included in the 25 man squad
    Best Players in last couple World Cups
    Compare my rankins to FIFA ranks

# %%
import pandas as pd
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
import opendatasets as od

import random
from scipy.stats import norm

# %% [markdown]
# ### Loading Data in from Kaggle API

# %% [markdown]
# f51999f5f297523ab16349d4112bd4ff

# %%
od.download("https://www.kaggle.com/datasets/davidcariboo/player-scores")
# Out:
# Skipping, found downloaded files in "./player-scores" (use force=True to force download)

# %% [markdown]
# ### Reading in the Kaggle tables for Transfer Markt

# %%
valuations = (r'/Users/mallon/Desktop/UCD Data Analytics for Finance/player-scores/player_valuations.csv')
players = (r'/Users/mallon/Desktop/UCD Data Analytics for Finance/player-scores/players.csv')
competitions = (r'/Users/mallon/Desktop/UCD Data Analytics for Finance/player-scores/competitions.csv')
clubs = (r'/Users/mallon/Desktop/UCD Data Analytics for Finance/player-scores/clubs.csv')

# %%
players= pd.read_csv(players)
valuations= pd.read_csv(valuations)
competitions= pd.read_csv(competitions)
clubs= pd.read_csv(clubs)

# %%
#current players only
still_playing = players['last_season'].isin([2018,2019,2020,2021, 2022])
players = players[still_playing]
players.head()
# Out:
#       player_id        pretty_name  club_id club_pretty_name  current_club_id  \
# 9645      96472     Ralf Seuntjens     1426        Vvv Venlo             1426
# 9646     234807   Martin Samuelsen     1426        Vvv Venlo             1426
# 9647     118292      Julian Michel      498      Ksc Lokeren              498
# 9648      12974  Killian Overmeire      498      Ksc Lokeren              498
# 9649      70170      Lukas Marecek      498      Ksc Lokeren              498
#
#      country_of_citizenship country_of_birth date_of_birth  position  \
# 9645            Netherlands      Netherlands    1989-04-17    Attack
# 9646                 Norway           Norway    1997-04-17    Attack
# 9647                 France           France    1992-02-19  Midfield
# 9648                Belgium          Belgium    1985-12-06  Midfield
# 9649         Czech Republic             CSSR    1990-04-17  Midfield
#
#             sub_position  ... height_in_cm market_value_in_gbp  \
# 9645      Centre-Forward  ...          194            495000.0
# 9646         Left Winger  ...          189            450000.0
# 9647    Central Midfield  ...          180                 NaN
# 9648  Defensive Midfield  ...          188                 NaN
# 9649  Defensive Midfield  ...          182            180000.0
#
#       highest_market_value_in_gbp              agent_name  \
# 9645                     675000.0  Sportconsult Nederland
# 9646                     720000.0           Jim Solbakken
# 9647                    1350000.0       Eleven Management
# 9648                    1800000.0        PROFI-MANAGEMENT
# 9649                    1350000.0                     NaN
#
#       contract_expiration_date domestic_competition_id    club_name image_url  \
# 9645                2024-01-31                     NL1    vvv-venlo       NaN
# 9646                2022-12-31                     NL1    vvv-venlo       NaN
# 9647                       NaN                     BE1  ksc-lokeren       NaN
# 9648                       NaN                     BE1  ksc-lokeren       NaN
# 9649                2022-06-30                     BE1  ksc-lokeren       NaN
#
#      last_season                                                url
# 9645        2018  https://www.transfermarkt.co.uk/ralf-seuntjens...
# 9646        2018  https://www.transfermarkt.co.uk/martin-samuels...
# 9647        2018  https://www.transfermarkt.co.uk/julian-michel/...
# 9648        2018  https://www.transfermarkt.co.uk/killian-overme...
# 9649        2018  https://www.transfermarkt.co.uk/lukas-marecek/...
#
# [5 rows x 22 columns]

# %%
valuations.head()
# Out:
#          date    datetime    dateweek  player_id  current_club_id  \
# 0  2013-07-22  2013-07-22  2013-07-22     254016              855
# 1  2014-01-14  2014-01-14  2014-01-13     254016              855
# 2  2008-08-25  2008-08-25  2008-08-25      51053               23
# 3  2011-05-30  2011-05-30  2011-05-30      51053               23
# 4  2011-08-26  2011-08-26  2011-08-22      51053               23
#
#    market_value player_club_domestic_competition_id
# 0         90000                                 FR1
# 1         90000                                 FR1
# 2         90000                                  L1
# 3         90000                                  L1
# 4        225000                                  L1

# %%
joined = pd.merge(left = players, right = valuations, how = 'inner', on = 'player_id' )
#firsttierplayersonly (revise later if no players for country)

# %%
joined = pd.merge(left = joined, right = clubs, how = 'inner', on = 'club_id' )
joined = pd.merge(left = joined, right = competitions, how = 'inner', left_on='player_club_domestic_competition_id', right_on='competition_id' )

# %%
#first_tier = joined['sub_type'] == 'first_tier'
toptierplayers = joined

# %%
toptierplayers['date'] = pd.to_datetime(toptierplayers['date'], errors='coerce')

# %%
toptierplayers['Year']= toptierplayers['date'].dt.year
grouped_multiple = toptierplayers.groupby(['player_id', 'Year']).agg({'market_value': ['mean']})
grouped_multiple.columns = ['market_value_mean']
grouped_multiple['market_value_mean']= grouped_multiple['market_value_mean'].astype(int)
players_avg_value_per_year = grouped_multiple.reset_index()
players_avg_value_per_year.head()
# Out:
#    player_id  Year  market_value_mean
# 0        532  2004            8550000
# 1        532  2005            9900000
# 2        532  2006           10125000
# 3        532  2007            9675000
# 4        532  2008            6900000

# %%
list=[x for x in range(2003, 2022+1)]
WorldCupList = {'World Cup': ['2006','2006','2006','2006', '2010', '2010','2010','2010','2014','2014','2014','2014','2018','2018','2018','2018','2022','2022','2022','2022'], 'Year': list}
WorldCupYears = pd.DataFrame(WorldCupList)

# %%
players_avg_value_per_wc = pd.merge(players_avg_value_per_year, WorldCupYears, left_on='Year', right_on='Year')
players_avg_value_per_wc = players_avg_value_per_wc.groupby(['player_id', 'World Cup']).agg({'market_value_mean': ['mean', 'min', 'max']})
players_avg_value_per_wc.columns = ['market_value_mean', 'market_value_min', 'market_value_max']
players_avg_value_per_wc['market_value_mean']= players_avg_value_per_wc['market_value_mean'].astype(int)
players_avg_value_per_wc = players_avg_value_per_wc.reset_index()

# %%
players_avg_value_per_wc = players_avg_value_per_wc.groupby(['player_id', 'World Cup']).agg({'market_value_mean': ['mean', 'min', 'max']})
players_avg_value_per_wc.columns = ['market_value_mean', 'market_value_min', 'market_value_max']
players_avg_value_per_wc = players_avg_value_per_wc.reset_index()

# %%
players_avg_value_per_wc
# Out:
#        player_id World Cup  market_value_mean  market_value_min  \
# 0            532      2006          9525000.0           9525000
# 1            532      2010          8268750.0           8268750
# 2            532      2014          3675416.0           3675416
# 3            532      2018           787500.0            787500
# 4            532      2022           405000.0            405000
# ...          ...       ...                ...               ...
# 36691    1048097      2022            50000.0             50000
# 36692    1048954      2022            50000.0             50000
# 36693    1050249      2022            75000.0             75000
# 36694    1050852      2022            50000.0             50000
# 36695    1056907      2022           100000.0            100000
#
#        market_value_max
# 0               9525000
# 1               8268750
# 2               3675416
# 3                787500
# 4                405000
# ...                 ...
# 36691             50000
# 36692             50000
# 36693             75000
# 36694             50000
# 36695            100000
#
# [36696 rows x 5 columns]

# %%
toptierplayers_per_wc = pd.merge(toptierplayers,players_avg_value_per_wc,on = 'player_id')

# %%
toptierplayers_per_wc.columns
# Out:
# Index(['player_id', 'pretty_name_x', 'club_id', 'club_pretty_name',
#        'current_club_id_x', 'country_of_citizenship', 'country_of_birth',
#        'date_of_birth', 'position', 'sub_position', 'name_x', 'foot',
#        'height_in_cm', 'market_value_in_gbp', 'highest_market_value_in_gbp',
#        'agent_name', 'contract_expiration_date', 'domestic_competition_id_x',
#        'club_name', 'image_url', 'last_season', 'url_x', 'date', 'datetime',
#        'dateweek', 'current_club_id_y', 'market_value',
#        'player_club_domestic_competition_id', 'name_y', 'pretty_name_y',
#        'domestic_competition_id_y', 'total_market_value', 'squad_size',
#        'average_age', 'foreigners_number', 'foreigners_percentage',
#        'national_team_players', 'stadium_name', 'stadium_seats',
#        'net_transfer_record', 'coach_name', 'url_y', 'competition_id',
#        'pretty_name', 'type', 'sub_type', 'country_id', 'country_name',
#        'country_latitude', 'country_longitude', 'domestic_league_code', 'name',
#        'confederation', 'url', 'Year', 'World Cup', 'market_value_mean',
#        'market_value_min', 'market_value_max'],
#       dtype='object')

# %%
WC_2022_teams = ['Qatar', 'Germany', 'Denmark', 'Brazil', 'France', 'Belgium', 'Croatia', 'Spain', 'Serbia', 'England', 'Switzerland', 'Netherlands', 'Argentina', 'Iran', 'Korea, South', 'Japan', 'Saudi Arabia', 'Ecuador', 'Uruguay', 'Canada', 'Ghana', 'Senegal', 'Portugal', 'Poland', 'Tunisia', 'Morocco', 'Cameroon', 'United States', 'Mexico', 'Wales', 'Australia', 'Costa Rica']

# %%
TopTier_2022_WC_Eligble_Players = toptierplayers_per_wc[toptierplayers_per_wc.country_of_citizenship.isin(WC_2022_teams)]
TopTier_2022_WC_Eligble_Players = TopTier_2022_WC_Eligble_Players[TopTier_2022_WC_Eligble_Players["World Cup"]== "2022"]

# %%
print(TopTier_2022_WC_Eligble_Players["country_of_citizenship"].unique())
# Out:
# ['Netherlands' 'Germany' 'England' 'Morocco' 'Belgium' 'Switzerland'
#  'Iran' 'Croatia' 'United States' 'Portugal' 'France' 'Serbia' 'Denmark'
#  'Ghana' 'Ecuador' 'Australia' 'Spain' 'Senegal' 'Japan' 'Wales' 'Brazil'
#  'Mexico' 'Argentina' 'Poland' 'Tunisia' 'Saudi Arabia' 'Costa Rica'
#  'Cameroon' 'Canada' 'Qatar' 'Uruguay' 'Korea, South']

# %%
TopTier_2022_WC_Eligble_Players =TopTier_2022_WC_Eligble_Players[['World Cup','player_id','pretty_name_x','country_of_citizenship','position','sub_position','date_of_birth','name','market_value_mean','market_value_min','market_value_max']]

# %%
TopTier_2022_WC_Eligble_Players.head(5)
# Out:
#    World Cup  player_id   pretty_name_x country_of_citizenship position  \
# 3       2022      96472  Ralf Seuntjens            Netherlands   Attack
# 7       2022      96472  Ralf Seuntjens            Netherlands   Attack
# 11      2022      96472  Ralf Seuntjens            Netherlands   Attack
# 15      2022      96472  Ralf Seuntjens            Netherlands   Attack
# 19      2022      96472  Ralf Seuntjens            Netherlands   Attack
#
#       sub_position date_of_birth        name  market_value_mean  \
# 3   Centre-Forward    1989-04-17  eredivisie           471125.0
# 7   Centre-Forward    1989-04-17  eredivisie           471125.0
# 11  Centre-Forward    1989-04-17  eredivisie           471125.0
# 15  Centre-Forward    1989-04-17  eredivisie           471125.0
# 19  Centre-Forward    1989-04-17  eredivisie           471125.0
#
#     market_value_min  market_value_max
# 3             471125            471125
# 7             471125            471125
# 11            471125            471125
# 15            471125            471125
# 19            471125            471125

# %%
TopTier_2022_WC_Eligble_Players = TopTier_2022_WC_Eligble_Players.drop_duplicates()

# %%
TopTier_2022_WC_Eligble_Players = TopTier_2022_WC_Eligble_Players.sort_values(by='market_value_mean',ascending=False)

# %%
TopTier_2022_WC_Eligble_Players.head(5)
# Out:
#        World Cup  player_id    pretty_name_x country_of_citizenship position  \
# 633985      2022     342229    Kylian Mbappe                 France   Attack
# 150608      2022     132098       Harry Kane                England   Attack
# 634231      2022      68290           Neymar                 Brazil   Attack
# 137350      2022      88755  Kevin De Bruyne                Belgium   Attack
# 161985      2022     134425  Raheem Sterling                England   Attack
#
#               sub_position date_of_birth            name  market_value_mean  \
# 633985      Centre-Forward    1998-12-20         ligue-1        175000000.0
# 150608      Centre-Forward    1993-07-28  premier-league        118333333.0
# 634231         Left Winger    1992-02-05         ligue-1        118250000.0
# 137350  Attacking Midfield    1991-06-28  premier-league        109791666.0
# 161985         Left Winger    1994-12-08  premier-league        108416666.0
#
#         market_value_min  market_value_max
# 633985         175000000         175000000
# 150608         118333333         118333333
# 634231         118250000         118250000
# 137350         109791666         109791666
# 161985         108416666         108416666

# %%
TopTier_2022_WC_Eligble_Players[TopTier_2022_WC_Eligble_Players['player_id'].isin([50202])]
# Out:
#        World Cup  player_id pretty_name_x country_of_citizenship position  \
# 211517      2022      50202   Eden Hazard                Belgium   Attack
#
#        sub_position date_of_birth    name  market_value_mean  \
# 211517  Left Winger    1991-01-07  laliga         65358333.0
#
#         market_value_min  market_value_max
# 211517          65358333          65358333

# %% [markdown]
# ## EA Sports FIFA Ratings

# %%
od.download("https://www.kaggle.com/datasets/sanjeetsinghnaik/fifa-23-players-dataset")
# Out:
# Skipping, found downloaded files in "./fifa-23-players-dataset" (use force=True to force download)

# %%
fifa23data = (r'/Users/mallon/Desktop/UCD Data Analytics for Finance/fifa-23-players-dataset/Fifa 23 Players Data.csv')
fifa23= pd.read_csv(fifa23data)

# %%
print(fifa23.columns)
# Out:
# Index(['Known As', 'Full Name', 'Overall', 'Potential', 'Value(in Euro)',
#        'Positions Played', 'Best Position', 'Nationality', 'Image Link', 'Age',
#        'Height(in cm)', 'Weight(in kg)', 'TotalStats', 'BaseStats',
#        'Club Name', 'Wage(in Euro)', 'Release Clause', 'Club Position',
#        'Contract Until', 'Club Jersey Number', 'Joined On', 'On Loan',
#        'Preferred Foot', 'Weak Foot Rating', 'Skill Moves',
#        'International Reputation', 'National Team Name',
#        'National Team Image Link', 'National Team Position',
#        'National Team Jersey Number', 'Attacking Work Rate',
#        'Defensive Work Rate', 'Pace Total', 'Shooting Total', 'Passing Total',
#        'Dribbling Total', 'Defending Total', 'Physicality Total', 'Crossing',
#        'Finishing', 'Heading Accuracy', 'Short Passing', 'Volleys',
#        'Dribbling', 'Curve', 'Freekick Accuracy', 'LongPassing', 'BallControl',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
#        'Composure', 'Marking', 'Standing Tackle', 'Sliding Tackle',
#        'Goalkeeper Diving', 'Goalkeeper Handling', ' GoalkeeperKicking',
#        'Goalkeeper Positioning', 'Goalkeeper Reflexes', 'ST Rating',
#        'LW Rating', 'LF Rating', 'CF Rating', 'RF Rating', 'RW Rating',
#        'CAM Rating', 'LM Rating', 'CM Rating', 'RM Rating', 'LWB Rating',
#        'CDM Rating', 'RWB Rating', 'LB Rating', 'CB Rating', 'RB Rating',
#        'GK Rating'],
#       dtype='object')

# %%
fifa23 = fifa23[['Full Name', 'Overall', 'Potential', 'Value(in Euro)',
       'Positions Played', 'Best Position', 'Nationality', 'Image Link', 'Age',
       'Height(in cm)', 'TotalStats', 
       'Club Name', 'Wage(in Euro)', 'Release Clause', 'Club Position', 'Club Jersey Number',
       'Skill Moves','International Reputation', 
        'National Team Name','National Team Image Link', 'National Team Position',
       'National Team Jersey Number','Finishing','Short Passing', 'Sprint Speed', 'Stamina', 'Strength', 'Penalties']]

# %%
fifa23.head(20)
# Out:
#                             Full Name  Overall  Potential  Value(in Euro)  \
# 0                        Lionel Messi       91         91        54000000
# 1                       Karim Benzema       91         91        64000000
# 2                  Robert Lewandowski       91         91        84000000
# 3                     Kevin De Bruyne       91         91       107500000
# 4                       Kylian Mbappé       91         95       190500000
# 5                       Mohamed Salah       90         90       115500000
# 6                    Thibaut Courtois       90         91        90000000
# 7                        Manuel Neuer       90         90        13500000
# 8        C. Ronaldo dos Santos Aveiro       90         90        41000000
# 9                     Virgil van Dijk       90         90        98000000
# 10                         Harry Kane       89         89       105500000
# 11         Neymar da Silva Santos Jr.       89         89        99500000
# 12                      Heung Min Son       89         89       101000000
# 13  Carlos Henrique Venancio Casimiro       89         89        86000000
# 14                          Jan Oblak       89         91        85500000
# 15                         Sadio Mané       89         89        99500000
# 16          Ederson Santana de Moraes       89         91        88000000
# 17                     Joshua Kimmich       89         90       105500000
# 18              Alisson Ramses Becker       89         90        79000000
# 19                       N'Golo Kanté       89         89        72000000
#
#    Positions Played Best Position     Nationality  \
# 0                RW           CAM       Argentina
# 1             CF,ST            CF          France
# 2                ST            ST          Poland
# 3            CM,CAM            CM         Belgium
# 4             ST,LW            ST          France
# 5                RW            RW           Egypt
# 6                GK            GK         Belgium
# 7                GK            GK         Germany
# 8                ST            ST        Portugal
# 9                CB            CB     Netherlands
# 10               ST            ST         England
# 11               LW            LW          Brazil
# 12            LW,LM            LW  Korea Republic
# 13              CDM           CDM          Brazil
# 14               GK            GK        Slovenia
# 15            LM,CF            LM         Senegal
# 16               GK            GK          Brazil
# 17           CDM,RB           CDM         Germany
# 18               GK            GK          Brazil
# 19           CDM,CM           CDM          France
#
#                                           Image Link  Age  Height(in cm)  ...  \
# 0   https://cdn.sofifa.net/players/158/023/23_60.png   35            169  ...
# 1   https://cdn.sofifa.net/players/165/153/23_60.png   34            185  ...
# 2   https://cdn.sofifa.net/players/188/545/23_60.png   33            185  ...
# 3   https://cdn.sofifa.net/players/192/985/23_60.png   31            181  ...
# 4   https://cdn.sofifa.net/players/231/747/23_60.png   23            182  ...
# 5   https://cdn.sofifa.net/players/209/331/23_60.png   30            175  ...
# 6   https://cdn.sofifa.net/players/192/119/23_60.png   30            199  ...
# 7   https://cdn.sofifa.net/players/167/495/23_60.png   36            193  ...
# 8   https://cdn.sofifa.net/players/020/801/23_60.png   37            187  ...
# 9   https://cdn.sofifa.net/players/203/376/23_60.png   30            193  ...
# 10  https://cdn.sofifa.net/players/202/126/23_60.png   28            188  ...
# 11  https://cdn.sofifa.net/players/190/871/23_60.png   30            175  ...
# 12  https://cdn.sofifa.net/players/200/104/23_60.png   29            183  ...
# 13  https://cdn.sofifa.net/players/200/145/23_60.png   30            185  ...
# 14  https://cdn.sofifa.net/players/200/389/23_60.png   29            188  ...
# 15  https://cdn.sofifa.net/players/208/722/23_60.png   30            174  ...
# 16  https://cdn.sofifa.net/players/210/257/23_60.png   28            188  ...
# 17  https://cdn.sofifa.net/players/212/622/23_60.png   27            177  ...
# 18  https://cdn.sofifa.net/players/212/831/23_60.png   29            191  ...
# 19  https://cdn.sofifa.net/players/215/914/23_60.png   31            168  ...
#
#     National Team Name                 National Team Image Link  \
# 0            Argentina      https://cdn.sofifa.net/flags/ar.png
# 1               France      https://cdn.sofifa.net/flags/fr.png
# 2               Poland      https://cdn.sofifa.net/flags/pl.png
# 3              Belgium      https://cdn.sofifa.net/flags/be.png
# 4               France      https://cdn.sofifa.net/flags/fr.png
# 5                    -                                        -
# 6              Belgium      https://cdn.sofifa.net/flags/be.png
# 7              Germany      https://cdn.sofifa.net/flags/de.png
# 8             Portugal      https://cdn.sofifa.net/flags/pt.png
# 9          Netherlands      https://cdn.sofifa.net/flags/nl.png
# 10             England  https://cdn.sofifa.net/flags/gb-eng.png
# 11                   -      https://cdn.sofifa.net/flags/br.png
# 12                   -                                        -
# 13                   -      https://cdn.sofifa.net/flags/br.png
# 14                   -                                        -
# 15                   -                                        -
# 16                   -      https://cdn.sofifa.net/flags/br.png
# 17             Germany      https://cdn.sofifa.net/flags/de.png
# 18                   -      https://cdn.sofifa.net/flags/br.png
# 19              France      https://cdn.sofifa.net/flags/fr.png
#
#     National Team Position  National Team Jersey Number Finishing  \
# 0                       RW                           10        90
# 1                       ST                           19        92
# 2                       ST                            9        94
# 3                       RF                            7        85
# 4                       ST                           10        93
# 5                        -                            -        93
# 6                       GK                            1        14
# 7                       GK                            1        13
# 8                       ST                            7        93
# 9                       CB                            4        52
# 10                      ST                            9        93
# 11                       -                            -        83
# 12                       -                            -        91
# 13                       -                            -        64
# 14                       -                            -        11
# 15                       -                            -        86
# 16                       -                            -        14
# 17                     CDM                            6        68
# 18                       -                            -        13
# 19                     CDM                           13        65
#
#    Short Passing  Sprint Speed  Stamina Strength Penalties
# 0             91            76       70       68        75
# 1             89            80       82       82        84
# 2             84            75       76       87        90
# 3             93            73       88       74        83
# 4             85            97       87       76        80
# 5             84            91       87       75        86
# 6             33            52       38       70        27
# 7             60            60       43       80        47
# 8             80            83       76       77        90
# 9             79            91       74       93        62
# 10            84            69       83       83        92
# 11            85            86       79       52        91
# 12            84            90       88       64        73
# 13            84            66       90       90        66
# 14            43            58       41       78        11
# 15            84            90       85       72        75
# 16            61            63       41       78        51
# 17            87            60       94       68        44
# 18            60            49       32       78        23
# 19            82            68       95       72        54
#
# [20 rows x 28 columns]

# %%
fifa23['Full Name']= fifa23['Full Name'].astype(str)
cols = ['Full Name']
fifa23[cols] = fifa23[cols].apply(lambda x: x.str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8'))

# %%
fifa23transfermarkt2022WC = pd.merge(left = fifa23, right = TopTier_2022_WC_Eligble_Players, how = 'left', left_on='Full Name', right_on='pretty_name_x' )

# %% [markdown]
# # Creating a Weighted Rating

# %%
#### Top 50 Players Per Country
def top_players(df):
  # Sort the data by overall in descending order
  df = df.sort_values(by="Overall", ascending=False)
  # Select the top 50 players
  df = df.head(50)
  return df

# %%
fifa23transfermarkt2022WC = fifa23transfermarkt2022WC.groupby("country_of_citizenship").apply(top_players)

# %%
fifa23transfermarkt2022WC=fifa23transfermarkt2022WC.reset_index(level=0, drop=True)

# %%
unique_positions = fifa23transfermarkt2022WC['position'].unique()

# %%
Positions = {}


# Split the DataFrame into multiple DataFrames based on the unique values

for value1 in unique_positions:
    value_df = fifa23transfermarkt2022WC[(fifa23transfermarkt2022WC['position'] == value1)]
    ## 28 Man Squad
    Positions[value1] = value_df

#sets a dataframe for each variation of country and each position

for key, value in Positions.items():
  # Create a DataFrame with the same name as the key
  globals()[key] = pd.DataFrame(value)

# %%
Attack=Attack[["Full Name","player_id","Overall","Potential","market_value_mean","Wage(in Euro)"]]
Midfield=Midfield[["Full Name","player_id","Overall","Potential","market_value_mean","Wage(in Euro)"]]
Defence=Defence[["Full Name","player_id","Overall","Potential","market_value_mean","Wage(in Euro)"]]

# %%
Attack[['player_id', "market_value_mean"]] = Attack[['player_id', "market_value_mean"]].astype(int)
Attack[['player_id', "market_value_mean"]] = Attack[['player_id', "market_value_mean"]].astype(int)
Attack[['player_id', "market_value_mean"]] = Attack[['player_id', "market_value_mean"]].astype(int)

# %%
Attack['normalised_rating'] = (0.6 * Attack['Overall'] + 0.2 * Attack["Potential"] + 0.1 * Attack['market_value_mean'] + 0.1 * Attack['Wage(in Euro)']) / (0.6 + 0.2 + 0.1 + 0.1)

# Normalize the values between 70 and 100
Attack['normalised_rating'] = (Attack['normalised_rating'] - Attack['normalised_rating'].min()) / (Attack['normalised_rating'].max() - Attack['normalised_rating'].min()) * 30 + 70

# %%
Attack = Attack[["player_id","normalised_rating"]]

# %%
fifa23transfermarkt2022WC = fifa23transfermarkt2022WC.merge(Attack, on="player_id", suffixes=("_fifa23transfermarkt2022WC", "_Attack"))

# %%
fifa23transfermarkt2022WC = fifa23transfermarkt2022WC.sort_values(by="normalised_rating", ascending=False)

# Plot the normalised_rating for each player
fifa23transfermarkt2022WC.plot(x="normalised_rating",y='Age', kind="line")

# Show the plot
plt.show()

# %%
fifa23transfermarkt2022WC
# Out:
#               Full Name  Overall  Potential  Value(in Euro) Positions Played  \
# 138       Kylian Mbappe       91         95       190500000            ST,LW
# 121          Harry Kane       89         89       105500000               ST
# 31      Kevin De Bruyne       91         91       107500000           CM,CAM
# 122     Raheem Sterling       86         86        72500000            LW,RW
# 326          Sadio Mane       89         89        99500000            LM,CF
# ..                  ...      ...        ...             ...              ...
# 236         Mizuki Arai       67         70         1300000        CAM,LM,LW
# 384           Juan Cruz       66         74         1900000               ST
# 368     Bojan Radulovic       61         68          675000               ST
# 410  Sebastian Tounekti       60         74          575000               LM
# 68        Samuel Nongoh       60         75          575000            RM,LM
#
#     Best Position Nationality  \
# 138            ST      France
# 121            ST     England
# 31             CM     Belgium
# 122            LW     England
# 326            LM     Senegal
# ..            ...         ...
# 236           CAM       Japan
# 384            ST   Argentina
# 368            ST      Serbia
# 410           CAM     Tunisia
# 68             LM    Cameroon
#
#                                            Image Link  Age  Height(in cm)  \
# 138  https://cdn.sofifa.net/players/231/747/23_60.png   23            182
# 121  https://cdn.sofifa.net/players/202/126/23_60.png   28            188
# 31   https://cdn.sofifa.net/players/192/985/23_60.png   31            181
# 122  https://cdn.sofifa.net/players/202/652/23_60.png   27            170
# 326  https://cdn.sofifa.net/players/208/722/23_60.png   30            174
# ..                                                ...  ...            ...
# 236  https://cdn.sofifa.net/players/270/969/23_60.png   25            170
# 384  https://cdn.sofifa.net/players/255/453/23_60.png   22            184
# 368  https://cdn.sofifa.net/players/243/831/23_60.png   22            192
# 410  https://cdn.sofifa.net/players/256/383/23_60.png   19            183
# 68   https://cdn.sofifa.net/players/271/242/23_60.png   18            179
#
#      ...       pretty_name_x country_of_citizenship  position  \
# 138  ...       Kylian Mbappe                 France    Attack
# 121  ...          Harry Kane                England    Attack
# 31   ...     Kevin De Bruyne                Belgium    Attack
# 122  ...     Raheem Sterling                England    Attack
# 326  ...          Sadio Mane                Senegal    Attack
# ..   ...                 ...                    ...       ...
# 236  ...         Mizuki Arai                  Japan    Attack
# 384  ...           Juan Cruz                  Spain    Attack
# 368  ...     Bojan Radulovic                 Serbia    Attack
# 410  ...  Sebastian Tounekti                Tunisia    Attack
# 68   ...       Samuel Nongoh               Cameroon    Attack
#
#            sub_position date_of_birth                name  market_value_mean  \
# 138      Centre-Forward    1998-12-20             ligue-1        175000000.0
# 121      Centre-Forward    1993-07-28      premier-league        118333333.0
# 31   Attacking Midfield    1991-06-28      premier-league        109791666.0
# 122         Left Winger    1994-12-08      premier-league        108416666.0
# 326         Left Winger    1992-04-10          bundesliga         97499999.0
# ..                  ...           ...                 ...                ...
# 236         Left Winger    1997-04-14  liga-portugal-bwin           144444.0
# 384        Right Winger    2000-04-25              laliga           141666.0
# 368      Centre-Forward    1999-12-29      premier-league           135000.0
# 410         Left Winger    2002-07-13          eredivisie           112666.0
# 68         Right Winger    2004-03-04           super-lig            50000.0
#
#      market_value_min market_value_max normalised_rating
# 138       175000000.0      175000000.0        100.000000
# 121       118333333.0      118333333.0         90.297363
# 31        109791666.0      109791666.0         88.853416
# 122       108416666.0      108416666.0         88.591391
# 326        97499999.0       97499999.0         86.713319
# ..                ...              ...               ...
# 236          144444.0         144444.0         70.016695
# 384          141666.0         141666.0         70.016390
# 368          135000.0         135000.0         70.014471
# 410          112666.0         112666.0         70.010646
# 68            50000.0          50000.0         70.000000
#
# [468 rows x 40 columns]

# %% [markdown]
# Add this value back in using playerid

# %% [markdown]
# # Preparing custom function for teams to play eachother

# %%
print(fifa23transfermarkt2022WC.columns)
# Out:
# Index(['Full Namenormalised_rating', 'Overallnormalised_rating',
#        'Potentialnormalised_rating', 'Value(in Euro)normalised_rating',
#        'Positions Playednormalised_rating', 'Best Positionnormalised_rating',
#        'Nationalitynormalised_rating', 'Image Linknormalised_rating',
#        'Agenormalised_rating', 'Height(in cm)normalised_rating',
#        ...
#        'market_value_mean_fifa23transfermarkt2022WC', 'market_value_min',
#        'market_value_max', 'Full Name_Attack', 'player_id', 'Overall_Attack',
#        'Potential_Attack', 'market_value_mean_Attack', 'Wage(in Euro)_Attack',
#        'normalised_rating_Attack'],
#       dtype='object', length=127)

# %% [markdown]
# ##### Adding GoalKeepers to the Defence Grouping

# %%
fifa23transfermarkt2022WC["position"] = fifa23transfermarkt2022WC["position"].replace("Goalkeeper", "Defender")

# %% [markdown]
# #### Splitting every country into their own DataFrame

# %%
unique_countries = fifa23transfermarkt2022WC['country_of_citizenship'].unique()
unique_positions = fifa23transfermarkt2022WC['position'].unique()

# %%
print(unique_countries)
print(unique_positions)
# Out:
# ['Argentina' 'Australia' 'Belgium' 'Brazil' 'Cameroon' 'Canada'
#  'Costa Rica' 'Croatia' 'Denmark' 'Ecuador' 'England' 'France' 'Germany'
#  'Ghana' 'Iran' 'Japan' 'Korea, South' 'Mexico' 'Morocco' 'Netherlands'
#  'Poland' 'Portugal' 'Qatar' 'Saudi Arabia' 'Senegal' 'Serbia' 'Spain'
#  'Switzerland' 'Tunisia' 'United States' 'Uruguay' 'Wales']
# ['Attack' 'Defender' 'Midfield']

# %%
# creating a dicttionary of each team split into seperate dataframes
WorldCupTeams = {}


# Split the DataFrame into multiple DataFrames based on the unique values

for value1 in unique_countries:
  for value2 in unique_positions:
    value_df = fifa23transfermarkt2022WC[(fifa23transfermarkt2022WC['country_of_citizenship'] == value1) & (fifa23transfermarkt2022WC['position'] == value2)]
    ## 28 Man Squad
    value_df = value_df.sort_values('Overall', ascending=False).head(9)
    WorldCupTeams[(value1, value2)] = value_df

#sets a dataframe for each variation of country and each position

for key, value in WorldCupTeams.items():
  # Create a DataFrame with the same name as the key
  globals()["_".join(key)] = pd.DataFrame(value)

# %%
Belgium_Attack.head(10)
# Out:
#             Full Name  Overall  Potential  Value(in Euro) Positions Played  \
# 3     Kevin De Bruyne       91         91       107500000           CM,CAM
# 45      Romelu Lukaku       86         86        68000000               ST
# 79   Yannick Carrasco       85         85        54500000               LM
# 95      Dries Mertens       84         84        18000000        CF,ST,CAM
# 120       Eden Hazard       84         84        35000000               LW
# 431      Hans Vanaken       80         80        20500000           CM,CAM
# 439    Thorgan Hazard       80         80        20500000            LM,CF
# 664     Adnan Januzaj       79         79        18500000            RW,LW
# 669  Leandro Trossard       79         79        18500000        LM,ST,CAM
#
#     Best Position Nationality  \
# 3              CM     Belgium
# 45             ST     Belgium
# 79             LM     Belgium
# 95             CF     Belgium
# 120            LW     Belgium
# 431            CM     Belgium
# 439            LM     Belgium
# 664            RW     Belgium
# 669            LM     Belgium
#
#                                            Image Link  Age  Height(in cm)  \
# 3    https://cdn.sofifa.net/players/192/985/23_60.png   31            181
# 45   https://cdn.sofifa.net/players/192/505/23_60.png   29            191
# 79   https://cdn.sofifa.net/players/208/418/23_60.png   28            181
# 95   https://cdn.sofifa.net/players/175/943/23_60.png   35            169
# 120  https://cdn.sofifa.net/players/183/277/23_60.png   31            175
# 431  https://cdn.sofifa.net/players/200/155/23_60.png   29            195
# 439  https://cdn.sofifa.net/players/203/486/23_60.png   29            175
# 664  https://cdn.sofifa.net/players/208/330/23_60.png   27            186
# 669  https://cdn.sofifa.net/players/207/421/23_60.png   27            171
#
#      ...  player_id     pretty_name_x  country_of_citizenship  position  \
# 3    ...    88755.0   Kevin De Bruyne                 Belgium    Attack
# 45   ...    96341.0     Romelu Lukaku                 Belgium    Attack
# 79   ...   140776.0  Yannick Carrasco                 Belgium    Attack
# 95   ...    56416.0     Dries Mertens                 Belgium    Attack
# 120  ...    50202.0       Eden Hazard                 Belgium    Attack
# 431  ...   137576.0      Hans Vanaken                 Belgium    Attack
# 439  ...   102226.0    Thorgan Hazard                 Belgium    Attack
# 664  ...   177847.0     Adnan Januzaj                 Belgium    Attack
# 669  ...   144028.0  Leandro Trossard                 Belgium    Attack
#
#            sub_position date_of_birth                name  market_value_mean  \
# 3    Attacking Midfield    1991-06-28      premier-league        109791666.0
# 45       Centre-Forward    1993-05-13             serie-a         81750000.0
# 79          Left Winger    1993-09-04              laliga         30750000.0
# 95       Centre-Forward    1987-05-06           super-lig         13654166.0
# 120         Left Winger    1991-01-07              laliga         65358333.0
# 431  Attacking Midfield    1992-08-24  jupiler-pro-league         14291666.0
# 439         Left Winger    1993-03-29          bundesliga         27833333.0
# 664        Right Winger    1995-02-05              laliga         10979166.0
# 669         Left Winger    1994-12-04      premier-league         17833333.0
#
#     market_value_min market_value_max
# 3        109791666.0      109791666.0
# 45        81750000.0       81750000.0
# 79        30750000.0       30750000.0
# 95        13654166.0       13654166.0
# 120       65358333.0       65358333.0
# 431       14291666.0       14291666.0
# 439       27833333.0       27833333.0
# 664       10979166.0       10979166.0
# 669       17833333.0       17833333.0
#
# [9 rows x 39 columns]

# %%
Brazil_Midfield.head(10)
# Out:
#           Full Name  Overall  Potential  Value(in Euro) Positions Played  \
# 7249  Victor Bobsin       67         78         2200000           CDM,CM
#
#      Best Position Nationality  \
# 7249            CM      Brazil
#
#                                             Image Link  Age  Height(in cm)  \
# 7249  https://cdn.sofifa.net/players/263/787/23_60.png   22            185
#
#       ...  player_id  pretty_name_x  country_of_citizenship  position  \
# 7249  ...   468323.0  Victor Bobsin                  Brazil  Midfield
#
#             sub_position date_of_birth                name  market_value_mean  \
# 7249  Defensive Midfield    2000-01-12  liga-portugal-bwin           800000.0
#
#      market_value_min market_value_max
# 7249         800000.0         800000.0
#
# [1 rows x 39 columns]

# %%
England_Attack.head(15)
# Out:
#            Full Name  Overall  Potential  Value(in Euro) Positions Played  \
# 10        Harry Kane       89         89       105500000               ST
# 47   Raheem Sterling       86         86        72500000            LW,RW
# 81       Jamie Vardy       85         85        23000000               ST
# 103    Jack Grealish       84         84        46000000        LW,LM,CAM
# 144      Mason Mount       84         87        57500000           CAM,RW
# 145     Jadon Sancho       84         88        61500000         LW,RW,LM
# 199   James Maddison       82         84        38000000           CAM,RM
# 222    Tammy Abraham       82         85        42000000               ST
# 324  Marcus Rashford       81         85        37000000            LW,ST
#
#     Best Position Nationality  \
# 10             ST     England
# 47             LW     England
# 81             ST     England
# 103            LW     England
# 144           CAM     England
# 145           CAM     England
# 199           CAM     England
# 222            ST     England
# 324            ST     England
#
#                                            Image Link  Age  Height(in cm)  \
# 10   https://cdn.sofifa.net/players/202/126/23_60.png   28            188
# 47   https://cdn.sofifa.net/players/202/652/23_60.png   27            170
# 81   https://cdn.sofifa.net/players/208/830/23_60.png   35            179
# 103  https://cdn.sofifa.net/players/206/517/23_60.png   26            180
# 144  https://cdn.sofifa.net/players/233/064/23_60.png   23            180
# 145  https://cdn.sofifa.net/players/233/049/23_60.png   22            180
# 199  https://cdn.sofifa.net/players/220/697/23_60.png   25            175
# 222  https://cdn.sofifa.net/players/231/352/23_60.png   24            195
# 324  https://cdn.sofifa.net/players/231/677/23_60.png   24            186
#
#      ...  player_id    pretty_name_x  country_of_citizenship  position  \
# 10   ...   132098.0       Harry Kane                 England    Attack
# 47   ...   134425.0  Raheem Sterling                 England    Attack
# 81   ...   197838.0      Jamie Vardy                 England    Attack
# 103  ...   203460.0    Jack Grealish                 England    Attack
# 144  ...   346483.0      Mason Mount                 England    Attack
# 145  ...   401173.0     Jadon Sancho                 England    Attack
# 199  ...   294057.0   James Maddison                 England    Attack
# 222  ...   331726.0    Tammy Abraham                 England    Attack
# 324  ...   258923.0  Marcus Rashford                 England    Attack
#
#            sub_position date_of_birth            name  market_value_mean  \
# 10       Centre-Forward    1993-07-28  premier-league        118333333.0
# 47          Left Winger    1994-12-08  premier-league        108416666.0
# 81       Centre-Forward    1987-01-11  premier-league         11958333.0
# 103         Left Winger    1995-09-10  premier-league         54237500.0
# 144  Attacking Midfield    1999-01-10  premier-league         53312500.0
# 145         Left Winger    2000-03-25  premier-league         95270833.0
# 199  Attacking Midfield    1996-11-23  premier-league         51812499.0
# 222      Centre-Forward    1997-10-02         serie-a         38645833.0
# 324         Left Winger    1997-10-31  premier-league         75333333.0
#
#     market_value_min market_value_max
# 10       118333333.0      118333333.0
# 47       108416666.0      108416666.0
# 81        11958333.0       11958333.0
# 103       54237500.0       54237500.0
# 144       53312500.0       53312500.0
# 145       95270833.0       95270833.0
# 199       51812499.0       51812499.0
# 222       38645833.0       38645833.0
# 324       75333333.0       75333333.0
#
# [9 rows x 39 columns]

# %%
def play_game(team1_def_rating,team1_mid_rating,team1_att_rating,team2_def_rating,team2_mid_rating,team2_att_rating):


  team1_rounds = 0
  team2_rounds = 0

  # Check if team 1's attack is greater than team 2's defense
  if (team1_att_rating["Overall"].mean() > team2_def_rating["Overall"].mean()):
    # Calculate the difference in ratings
    rating_diff = team1_att_rating["Overall"].mean() - team2_def_rating["Overall"].mean()
    # Calculate the probability of a normal distribution with a mean equal to the difference in ratings
    # and a standard deviation of 1
    probability = norm.cdf(rating_diff, 1)
    # Generate a random number between 0 and 1
    rand = random.random()
    # If the random number is less than the probability of winning, team 1 wins a round
    if rand < probability:
      team1_rounds += 1

    print(round(team1_att_rating["Overall"].mean(),2) , "Team1 Attack") 
    print(round(team1_mid_rating["Overall"].mean(),2) , "Team1 Midfield")
    print(round(team1_def_rating["Overall"].mean(),2) , "Team1 Defending")
    print(round(team2_def_rating["Overall"].mean(),2) , "Team2 Defending")
    print(round(team2_mid_rating["Overall"].mean(),2) , "Team2 Midfield") 
    print(round(team2_att_rating["Overall"].mean(),2) , "Team2 Attacking") 
    
  # Check if team 2's attack is greater than team 1's defense
  if (team2_att_rating["Overall"].mean() > team1_def_rating["Overall"].mean()):
    # Calculate the difference in ratings
    rating_diff = team2_att_rating["Overall"].mean() - team1_def_rating["Overall"].mean()
    # Calculate the probability of a normal distribution with a mean equal to the difference in ratings
    # and a standard deviation of 1
    probability = norm.cdf(rating_diff, 1)
    # Generate a random number between 0 and 1
    rand = random.random()
    # If the random number is less than the probability of winning, team 1 wins a round
    if rand < probability:
      team2_rounds += 1
    
 

   # Check if team 2's midfield is greater than team 1's midfield
  if (team2_mid_rating["Overall"].mean() > team1_mid_rating["Overall"].mean()):
    # Calculate the difference in ratings
    rating_diff = team2_mid_rating["Overall"].mean() - team1_mid_rating["Overall"].mean()
    # Calculate the probability of a normal distribution with a mean equal to the difference in ratings
    # and a standard deviation of 1
    probability = norm.cdf(rating_diff, 1)
    # Generate a random number between 0 and 1
    rand = random.random()
    # If the random number is less than the probability of winning, team 2 wins a round
    if rand < probability:
      team2_rounds += 1
    
    
    print(round(team1_att_rating["Overall"].mean(),2) , "Team1 Attack") 
    print(round(team1_mid_rating["Overall"].mean(),2) , "Team1 Midfield")
    print(round(team1_def_rating["Overall"].mean(),2) , "Team1 Defending")
    print(round(team2_def_rating["Overall"].mean(),2) , "Team2 Defending")
    print(round(team2_mid_rating["Overall"].mean(),2) , "Team2 Midfield") 
    print(round(team2_att_rating["Overall"].mean(),2) , "Team2 Attacking") 
   
    

  if team1_rounds > team2_rounds:
    #Adding Form to a team, if they win their Overall goes up by 1, down 1 for a loss and the same for a draw
    
    # Add 2 to the overall of every player in team 1
    team1_def_rating["Overall"] += 1
    team1_mid_rating["Overall"] += 1
    team1_att_rating["Overall"] += 1
    
    # Subtract 1 from the overall of every player in team 2
    team2_def_rating["Overall"] -= 1
    team2_mid_rating["Overall"] -= 1
    team2_att_rating["Overall"] -= 1
    return "Team 1 wins!"
  elif team1_rounds < team2_rounds:
    
    # Add 2 to the overall of every player in team 2
    team2_def_rating["Overall"] += 1
    team2_mid_rating["Overall"] += 1
    team2_att_rating["Overall"] += 1
    
    # Subtract 1 from the overall of every player in team 1
    team1_def_rating["Overall"] -= 1
    team1_mid_rating["Overall"] -= 1
    team1_att_rating["Overall"] -= 1
    return "Team 2 wins!"
  else:
    return "It's a draw!"

# %%
Belgium_Defender
# Out:
#              Full Name  Overall  Potential  Value(in Euro) Positions Played  \
# 6     Thibaut Courtois       89         91        90000000               GK
# 114      Koen Casteels       83         85        31500000               GK
# 259  Toby Alderweireld       81         82        14500000               CB
# 337     Jan Vertonghen       80         81         7000000               CB
# 456     Simon Mignolet       79         80         3600000               GK
# 625          Matz Sels       78         80        13000000               GK
# 776   Timothy Castagne       77         80        16000000            RB,LB
# 802     Thomas Meunier       77         78        12000000            RB,RM
# 908          Wout Faes       76         82        14500000               CB
#
#     Best Position Nationality  \
# 6              GK     Belgium
# 114            GK     Belgium
# 259            CB     Belgium
# 337            CB     Belgium
# 456            GK     Belgium
# 625            GK     Belgium
# 776           RWB     Belgium
# 802            RB     Belgium
# 908            CB     Belgium
#
#                                            Image Link  Age  Height(in cm)  \
# 6    https://cdn.sofifa.net/players/192/119/23_60.png   30            199
# 114  https://cdn.sofifa.net/players/192/984/23_60.png   30            197
# 259  https://cdn.sofifa.net/players/184/087/23_60.png   33            186
# 337  https://cdn.sofifa.net/players/172/871/23_60.png   35            191
# 456  https://cdn.sofifa.net/players/173/426/23_60.png   34            193
# 625  https://cdn.sofifa.net/players/199/641/23_60.png   30            190
# 776  https://cdn.sofifa.net/players/222/501/23_60.png   26            185
# 802  https://cdn.sofifa.net/players/202/371/23_60.png   30            191
# 908  https://cdn.sofifa.net/players/235/036/23_60.png   24            187
#
#      ...  player_id      pretty_name_x  country_of_citizenship  position  \
# 6    ...   108390.0   Thibaut Courtois                 Belgium  Defender
# 114  ...   108880.0      Koen Casteels                 Belgium  Defender
# 259  ...    42710.0  Toby Alderweireld                 Belgium  Defender
# 337  ...    43250.0     Jan Vertonghen                 Belgium  Defender
# 456  ...    50219.0     Simon Mignolet                 Belgium  Defender
# 625  ...   127202.0          Matz Sels                 Belgium  Defender
# 776  ...   262226.0   Timothy Castagne                 Belgium  Defender
# 802  ...   100986.0     Thomas Meunier                 Belgium  Defender
# 908  ...   292808.0          Wout Faes                 Belgium  Defender
#
#     sub_position date_of_birth                name  market_value_mean  \
# 6            NaN    1992-05-11              laliga         60604166.0
# 114          NaN    1992-06-25          bundesliga         11500000.0
# 259  Centre-Back    1989-03-02  jupiler-pro-league         20041666.0
# 337  Centre-Back    1987-04-24  jupiler-pro-league         10983333.0
# 456          NaN    1988-03-06  jupiler-pro-league          7541666.0
# 625          NaN    1992-02-26             ligue-1          7041666.0
# 776   Right-Back    1995-12-05      premier-league         22499999.0
# 802   Right-Back    1991-09-12          bundesliga         17562500.0
# 908  Centre-Back    1998-04-03      premier-league          6795833.0
#
#     market_value_min market_value_max
# 6         60604166.0       60604166.0
# 114       11500000.0       11500000.0
# 259       20041666.0       20041666.0
# 337       10983333.0       10983333.0
# 456        7541666.0        7541666.0
# 625        7041666.0        7041666.0
# 776       22499999.0       22499999.0
# 802       17562500.0       17562500.0
# 908        6795833.0        6795833.0
#
# [9 rows x 39 columns]

# %%
England_Defender
# Out:
#            Full Name  Overall  Potential  Value(in Euro) Positions Played  \
# 69       Kyle Walker       86         85        37500000               RB
# 137      Reece James       85         88        57000000           RWB,RB
# 146    Fikayo Tomori       85         90        60500000               CB
# 117  Kieran Trippier       85         84        30500000            RB,RM
# 195      John Stones       84         84        34500000               CB
# 236   Aaron Ramsdale       83         86        34500000               GK
# 243     Ben Chilwell       83         85        37000000           LWB,LB
# 246  Jordan Pickford       83         84        26000000               GK
# 308    Harry Maguire       82         82        24000000               CB
#
#     Best Position Nationality  \
# 69             RB     England
# 137           RWB     England
# 146            CB     England
# 117            RB     England
# 195            CB     England
# 236            GK     England
# 243           LWB     England
# 246            GK     England
# 308            CB     England
#
#                                            Image Link  Age  Height(in cm)  \
# 69   https://cdn.sofifa.net/players/188/377/23_60.png   32            183
# 137  https://cdn.sofifa.net/players/238/074/23_60.png   22            178
# 146  https://cdn.sofifa.net/players/232/756/23_60.png   24            185
# 117  https://cdn.sofifa.net/players/186/345/23_60.png   31            173
# 195  https://cdn.sofifa.net/players/203/574/23_60.png   28            188
# 236  https://cdn.sofifa.net/players/233/934/23_60.png   24            191
# 243  https://cdn.sofifa.net/players/229/984/23_60.png   25            180
# 246  https://cdn.sofifa.net/players/204/935/23_60.png   28            185
# 308  https://cdn.sofifa.net/players/203/263/23_60.png   29            194
#
#      ...  player_id    pretty_name_x  country_of_citizenship  position  \
# 69   ...    95424.0      Kyle Walker                 England  Defender
# 137  ...   472423.0      Reece James                 England  Defender
# 146  ...   303254.0    Fikayo Tomori                 England  Defender
# 117  ...    95810.0  Kieran Trippier                 England  Defender
# 195  ...   186590.0      John Stones                 England  Defender
# 236  ...   427568.0   Aaron Ramsdale                 England  Defender
# 243  ...   316125.0     Ben Chilwell                 England  Defender
# 246  ...   130164.0  Jordan Pickford                 England  Defender
# 308  ...   177907.0    Harry Maguire                 England  Defender
#
#     sub_position date_of_birth            name  market_value_mean  \
# 69    Right-Back    1990-05-28  premier-league         33958333.0
# 137   Right-Back    1999-12-08  premier-league         36447916.0
# 146  Centre-Back    1997-12-19         serie-a         28312499.0
# 117   Right-Back    1990-09-19  premier-league         23416666.0
# 195  Centre-Back    1994-05-28  premier-league         38166666.0
# 236          NaN    1998-05-14  premier-league         16499999.0
# 243    Left-Back    1996-12-21  premier-league         42062500.0
# 246          NaN    1994-03-07  premier-league         28333333.0
# 308  Centre-Back    1993-03-05  premier-league         48062499.0
#
#     market_value_min market_value_max
# 69        33958333.0       33958333.0
# 137       36447916.0       36447916.0
# 146       28312499.0       28312499.0
# 117       23416666.0       23416666.0
# 195       38166666.0       38166666.0
# 236       16499999.0       16499999.0
# 243       42062500.0       42062500.0
# 246       28333333.0       28333333.0
# 308       48062499.0       48062499.0
#
# [9 rows x 39 columns]

# %%
play_game(Belgium_Defender,Belgium_Midfield,Belgium_Attack,England_Defender,England_Midfield,England_Attack)
# Out:
# 83.11 Team1 Attack
# 77.33 Team1 Midfield
# 81.0 Team1 Defending
# 83.0 Team2 Defending
# 81.78 Team2 Midfield
# 84.11 Team2 Attacking
# 83.11 Team1 Attack
# 77.33 Team1 Midfield
# 81.0 Team1 Defending
# 83.0 Team2 Defending
# 81.78 Team2 Midfield
# 84.11 Team2 Attacking
# 'Team 2 wins!'

# %%
play_game(Germany_Defender,Germany_Midfield,Germany_Attack,England_Defender,England_Midfield,England_Attack)
# Out:
# "It's a draw!"

# %%
play_game(Germany_Defender,Germany_Midfield,Germany_Attack,England_Defender,England_Midfield,England_Attack)
# Out:
# "It's a draw!"

# %%
play_game(Wales_Defender,Wales_Midfield,Wales_Attack,Germany_Defender,Germany_Midfield,Germany_Attack)
# Out:
# 74.89 Team1 Attack
# 66.0 Team1 Midfield
# 73.89 Team1 Defending
# 84.56 Team2 Defending
# 84.0 Team2 Midfield
# 83.67 Team2 Attacking
# 'Team 2 wins!'

# %%
WorldCupTeams
# Out:
# {('France',
#   'Attack'):               Full Name  Overall  Potential  Value(in Euro) Positions Played  \
#  4         Kylian Mbappe       91         95       190500000            ST,LW
#  1         Karim Benzema       91         91        64000000            CF,ST
#  56       Kingsley Coman       86         87        80000000               LM
#  61   Christopher Nkunku       86         89        94000000        CF,CAM,ST
#  66          Nabil Fekir       85         85        54500000              CAM
#  127        Moussa Diaby       84         88        61500000         RM,LM,LW
#  109   Wissam Ben Yedder       84         84        35500000               ST
#  192   Antoine Griezmann       83         83        30500000         ST,CF,RW
#  156     Ousmane Dembele       83         86        48000000            RW,LW
#
#      Best Position Nationality  \
#  4              ST      France
#  1              CF      France
#  56             LM      France
#  61            CAM      France
#  66            CAM      France
#  127            RM      France
#  109            CF      France
#  192           CAM      France
#  156            LM      France
#
#                                             Image Link  Age  Height(in cm)  \
#  4    https://cdn.sofifa.net/players/231/747/23_60.png   23            182
#  1    https://cdn.sofifa.net/players/165/153/23_60.png   34            185
#  56   https://cdn.sofifa.net/players/213/345/23_60.png   26            179
#  61   https://cdn.sofifa.net/players/232/411/23_60.png   24            175
#  66   https://cdn.sofifa.net/players/216/594/23_60.png   28            173
#  127  https://cdn.sofifa.net/players/241/852/23_60.png   22            171
#  109  https://cdn.sofifa.net/players/199/451/23_60.png   31            170
#  192  https://cdn.sofifa.net/players/194/765/23_60.png   31            176
#  156  https://cdn.sofifa.net/players/231/443/23_60.png   25            178
#
#       ...       pretty_name_x country_of_citizenship  position  \
#  4    ...       Kylian Mbappe                 France    Attack
#  1    ...       Karim Benzema                 France    Attack
#  56   ...      Kingsley Coman                 France    Attack
#  61   ...  Christopher Nkunku                 France    Attack
#  66   ...         Nabil Fekir                 France    Attack
#  127  ...        Moussa Diaby                 France    Attack
#  109  ...   Wissam Ben Yedder                 France    Attack
#  192  ...   Antoine Griezmann                 France    Attack
#  156  ...     Ousmane Dembele                 France    Attack
#
#             sub_position date_of_birth        name  market_value_mean  \
#  4        Centre-Forward    1998-12-20     ligue-1        175000000.0
#  1        Centre-Forward    1987-12-19      laliga         31500000.0
#  56         Right Winger    1996-06-13  bundesliga         55166666.0
#  61       Second Striker    1997-11-14  bundesliga         41733333.0
#  66   Attacking Midfield    1993-07-18      laliga         36749999.0
#  127         Left Winger    1999-07-07  bundesliga         35437500.0
#  109      Centre-Forward    1990-08-12     ligue-1         34291666.0
#  192      Second Striker    1991-03-21      laliga         74500000.0
#  156        Right Winger    1997-05-15      laliga         61749999.0
#
#       market_value_min market_value_max  rank
#  4         175000000.0      175000000.0   1.0
#  1          31500000.0       31500000.0  90.0
#  56         55166666.0       55166666.0  31.0
#  61         41733333.0       41733333.0  58.0
#  66         36749999.0       36749999.0  75.0
#  127        35437500.0       35437500.0  81.0
#  109        34291666.0       34291666.0  83.0
#  192        74500000.0       74500000.0  14.0
#  156        61749999.0       61749999.0  21.0
#
#  [9 rows x 40 columns],
#  ('France',
#   'Midfield'):                Full Name  Overall  Potential  Value(in Euro) Positions Played  \
#  74            Paul Pogba       85         85        52500000        CM,CDM,LM
#  232  Aurelien Tchouameni       82         89        61500000           CM,CDM
#  374  Benjamin Bourigeaud       81         81        26000000         RW,RM,LM
#  367     Corentin Tolisso       81         81        27500000           CM,CDM
#  399      Boubacar Kamara       80         86        31000000              CDM
#  458       Etienne Capoue       80         80        13000000           CM,CDM
#  462     Francis Coquelin       80         80        17500000        CM,LM,CDM
#  418      Jonathan Clauss       80         80        18500000              RWB
#  498        Adrien Rabiot       80         81        24000000            CM,LM
#
#      Best Position Nationality  \
#  74             CM      France
#  232           CDM      France
#  374            RW      France
#  367            CM      France
#  399           CDM      France
#  458            CM      France
#  462            CM      France
#  418           RWB      France
#  498            CM      France
#
#                                             Image Link  Age  Height(in cm)  \
#  74   https://cdn.sofifa.net/players/195/864/23_60.png   29            191
#  232  https://cdn.sofifa.net/players/241/637/23_60.png   22            187
#  374  https://cdn.sofifa.net/players/214/097/23_60.png   28            178
#  367  https://cdn.sofifa.net/players/219/683/23_60.png   27            181
#  399  https://cdn.sofifa.net/players/236/987/23_60.png   22            184
#  458  https://cdn.sofifa.net/players/178/213/23_60.png   33            190
#  462  https://cdn.sofifa.net/players/189/271/23_60.png   31            176
#  418  https://cdn.sofifa.net/players/239/093/23_60.png   29            178
#  498  https://cdn.sofifa.net/players/210/008/23_60.png   27            192
#
#       ...        pretty_name_x country_of_citizenship  position  \
#  74   ...           Paul Pogba                 France  Midfield
#  232  ...  Aurelien Tchouameni                 France  Midfield
#  374  ...  Benjamin Bourigeaud                 France  Midfield
#  367  ...     Corentin Tolisso                 France  Midfield
#  399  ...      Boubacar Kamara                 France  Midfield
#  458  ...       Etienne Capoue                 France  Midfield
#  462  ...     Francis Coquelin                 France  Midfield
#  418  ...      Jonathan Clauss                 France  Midfield
#  498  ...        Adrien Rabiot                 France  Midfield
#
#             sub_position date_of_birth            name  market_value_mean  \
#  74     Central Midfield    1993-03-15         serie-a         67874999.0
#  232  Defensive Midfield    2000-01-27          laliga         32833333.0
#  374      Right Midfield    1994-01-14         ligue-1         15125000.0
#  367    Central Midfield    1994-08-03         ligue-1         25562500.0
#  399  Defensive Midfield    1999-11-23  premier-league         26437499.0
#  458  Defensive Midfield    1988-07-11          laliga          4254166.0
#  462  Defensive Midfield    1991-05-13          laliga         11124999.0
#  418      Right Midfield    1992-09-25         ligue-1          5562500.0
#  498    Central Midfield    1995-04-03         serie-a         26541666.0
#
#       market_value_min market_value_max   rank
#  74         67874999.0       67874999.0   16.0
#  232        32833333.0       32833333.0   88.0
#  374        15125000.0       15125000.0  285.0
#  367        25562500.0       25562500.0  143.0
#  399        26437499.0       26437499.0  129.0
#  458         4254166.0        4254166.0  841.0
#  462        11124999.0       11124999.0  403.0
#  418         5562500.0        5562500.0  715.0
#  498        26541666.0       26541666.0  128.0
#
#  [9 rows x 40 columns],
#  ('France',
#   'Defender'):             Full Name  Overall  Potential  Value(in Euro) Positions Played  \
#  33        Hugo Lloris       87         87         9000000               GK
#  37       Mike Maignan       87         90        80000000               GK
#  86     Theo Hernandez       85         90        76000000               LB
#  91    Lucas Hernandez       84         86        46000000            CB,LB
#  108    Raphael Varane       84         85        39000000               CB
#  130      Jules Kounde       84         89        57500000            CB,RB
#  163     Ferland Mendy       83         84        38000000               LB
#  161  Presnel Kimpembe       83         86        42000000               CB
#  266       Lucas Digne       82         82        27500000               LB
#
#      Best Position Nationality  \
#  33             GK      France
#  37             GK      France
#  86            LWB      France
#  91             CB      France
#  108            CB      France
#  130            CB      France
#  163            LB      France
#  161            CB      France
#  266            LB      France
#
#                                             Image Link  Age  Height(in cm)  \
#  33   https://cdn.sofifa.net/players/167/948/23_60.png   35            188
#  37   https://cdn.sofifa.net/players/215/698/23_60.png   26            191
#  86   https://cdn.sofifa.net/players/232/656/23_60.png   24            184
#  91   https://cdn.sofifa.net/players/220/814/23_60.png   26            184
#  108  https://cdn.sofifa.net/players/201/535/23_60.png   29            191
#  130  https://cdn.sofifa.net/players/241/486/23_60.png   23            181
#  163  https://cdn.sofifa.net/players/228/618/23_60.png   27            180
#  161  https://cdn.sofifa.net/players/225/850/23_60.png   26            189
#  266  https://cdn.sofifa.net/players/200/458/23_60.png   28            178
#
#       ...     pretty_name_x country_of_citizenship  position  sub_position  \
#  33   ...       Hugo Lloris                 France  Defender           NaN
#  37   ...      Mike Maignan                 France  Defender           NaN
#  86   ...    Theo Hernandez                 France  Defender     Left-Back
#  91   ...   Lucas Hernandez                 France  Defender   Centre-Back
#  108  ...    Raphael Varane                 France  Defender   Centre-Back
#  130  ...      Jules Kounde                 France  Defender   Centre-Back
#  163  ...     Ferland Mendy                 France  Defender     Left-Back
#  161  ...  Presnel Kimpembe                 France  Defender   Centre-Back
#  266  ...       Lucas Digne                 France  Defender     Left-Back
#
#      date_of_birth            name  market_value_mean  market_value_min  \
#  33     1986-12-26  premier-league         12520833.0        12520833.0
#  37     1995-07-03         serie-a         24281250.0        24281250.0
#  86     1997-10-06         serie-a         41270833.0        41270833.0
#  91     1996-02-14      bundesliga         54249999.0        54249999.0
#  108    1993-04-25  premier-league         64916666.0        64916666.0
#  130    1998-11-12          laliga         41895833.0        41895833.0
#  163    1995-06-08          laliga         39812500.0        39812500.0
#  161    1995-08-13         ligue-1         36000000.0        36000000.0
#  266    1993-07-20  premier-league         29916666.0        29916666.0
#
#      market_value_max   rank
#  33        12520833.0  365.0
#  37        24281250.0  158.0
#  86        41270833.0   62.0
#  91        54249999.0   34.0
#  108       64916666.0   19.0
#  130       41895833.0   57.0
#  163       39812500.0   64.0
#  161       36000000.0   79.0
#  266       29916666.0  103.0
#
#  [9 rows x 40 columns],
#  ('England',
#   'Attack'):            Full Name  Overall  Potential  Value(in Euro) Positions Played  \
#  10        Harry Kane       89         89       105500000               ST
#  47   Raheem Sterling       86         86        72500000            LW,RW
#  81       Jamie Vardy       85         85        23000000               ST
#  145     Jadon Sancho       84         88        61500000         LW,RW,LM
#  103    Jack Grealish       84         84        46000000        LW,LM,CAM
#  144      Mason Mount       84         87        57500000           CAM,RW
#  199   James Maddison       82         84        38000000           CAM,RM
#  222    Tammy Abraham       82         85        42000000               ST
#  324  Marcus Rashford       81         85        37000000            LW,ST
#
#      Best Position Nationality  \
#  10             ST     England
#  47             LW     England
#  81             ST     England
#  145           CAM     England
#  103            LW     England
#  144           CAM     England
#  199           CAM     England
#  222            ST     England
#  324            ST     England
#
#                                             Image Link  Age  Height(in cm)  \
#  10   https://cdn.sofifa.net/players/202/126/23_60.png   28            188
#  47   https://cdn.sofifa.net/players/202/652/23_60.png   27            170
#  81   https://cdn.sofifa.net/players/208/830/23_60.png   35            179
#  145  https://cdn.sofifa.net/players/233/049/23_60.png   22            180
#  103  https://cdn.sofifa.net/players/206/517/23_60.png   26            180
#  144  https://cdn.sofifa.net/players/233/064/23_60.png   23            180
#  199  https://cdn.sofifa.net/players/220/697/23_60.png   25            175
#  222  https://cdn.sofifa.net/players/231/352/23_60.png   24            195
#  324  https://cdn.sofifa.net/players/231/677/23_60.png   24            186
#
#       ...    pretty_name_x country_of_citizenship  position  \
#  10   ...       Harry Kane                England    Attack
#  47   ...  Raheem Sterling                England    Attack
#  81   ...      Jamie Vardy                England    Attack
#  145  ...     Jadon Sancho                England    Attack
#  103  ...    Jack Grealish                England    Attack
#  144  ...      Mason Mount                England    Attack
#  199  ...   James Maddison                England    Attack
#  222  ...    Tammy Abraham                England    Attack
#  324  ...  Marcus Rashford                England    Attack
#
#             sub_position date_of_birth            name  market_value_mean  \
#  10       Centre-Forward    1993-07-28  premier-league        118333333.0
#  47          Left Winger    1994-12-08  premier-league        108416666.0
#  81       Centre-Forward    1987-01-11  premier-league         11958333.0
#  145         Left Winger    2000-03-25  premier-league         95270833.0
#  103         Left Winger    1995-09-10  premier-league         54237500.0
#  144  Attacking Midfield    1999-01-10  premier-league         53312500.0
#  199  Attacking Midfield    1996-11-23  premier-league         51812499.0
#  222      Centre-Forward    1997-10-02         serie-a         38645833.0
#  324         Left Winger    1997-10-31  premier-league         75333333.0
#
#       market_value_min market_value_max   rank
#  10        118333333.0      118333333.0    2.0
#  47        108416666.0      108416666.0    4.0
#  81         11958333.0       11958333.0  381.0
#  145        95270833.0       95270833.0    6.0
#  103        54237500.0       54237500.0   35.0
#  144        53312500.0       53312500.0   37.0
#  199        51812499.0       51812499.0   38.0
#  222        38645833.0       38645833.0   67.0
#  324        75333333.0       75333333.0   13.0
#
#  [9 rows x 40 columns],
#  ('England',
#   'Midfield'):             Full Name  Overall  Potential  Value(in Euro) Positions Played  \
#  83         Phil Foden       85         92       109500000        LW,CF,CAM
#  143       Declan Rice       84         87        52000000              CDM
#  125   Jude Bellingham       84         91        81500000            CM,LM
#  187  Jordan Henderson       83         83        28500000           CM,CDM
#  230       Bukayo Saka       82         89        60500000            RM,LM
#  362   Kalvin Phillips       81         85        32000000           CDM,CM
#  378     Harvey Barnes       80         83        29000000            LM,LW
#  514   Conor Gallagher       79         86        35500000               CM
#  767      James Milner       78         78         4400000         CM,LB,RB
#
#      Best Position Nationality  \
#  83            CAM     England
#  143           CDM     England
#  125            CM     England
#  187            CM     England
#  230            LM     England
#  362           CDM     England
#  378           CAM     England
#  514            CM     England
#  767           CDM     England
#
#                                             Image Link  Age  Height(in cm)  \
#  83   https://cdn.sofifa.net/players/237/692/23_60.png   22            171
#  143  https://cdn.sofifa.net/players/234/378/23_60.png   23            185
#  125  https://cdn.sofifa.net/players/252/371/23_60.png   19            186
#  187  https://cdn.sofifa.net/players/183/711/23_60.png   32            182
#  230  https://cdn.sofifa.net/players/246/669/23_60.png   20            178
#  362  https://cdn.sofifa.net/players/224/081/23_60.png   26            178
#  378  https://cdn.sofifa.net/players/234/742/23_60.png   24            180
#  514  https://cdn.sofifa.net/players/238/216/23_60.png   22            182
#  767  https://cdn.sofifa.net/players/138/412/23_60.png   36            175
#
#       ...     pretty_name_x country_of_citizenship  position  \
#  83   ...        Phil Foden                England  Midfield
#  143  ...       Declan Rice                England  Midfield
#  125  ...   Jude Bellingham                England  Midfield
#  187  ...  Jordan Henderson                England  Midfield
#  230  ...       Bukayo Saka                England  Midfield
#  362  ...   Kalvin Phillips                England  Midfield
#  378  ...     Harvey Barnes                England  Midfield
#  514  ...   Conor Gallagher                England  Midfield
#  767  ...      James Milner                England  Midfield
#
#             sub_position date_of_birth            name  market_value_mean  \
#  83     Central Midfield    2000-05-28  premier-league         61208333.0
#  143  Defensive Midfield    1999-01-14  premier-league         61500000.0
#  125    Central Midfield    2003-06-29      bundesliga         41979166.0
#  187    Central Midfield    1990-06-17  premier-league         24500000.0
#  230      Right Midfield    2001-09-05  premier-league         44395833.0
#  362  Defensive Midfield    1995-12-02  premier-league         27562499.0
#  378       Left Midfield    1997-12-09  premier-league         25541666.0
#  514    Central Midfield    2000-02-06  premier-league         13258333.0
#  767    Central Midfield    1986-01-04  premier-league          6166666.0
#
#       market_value_min market_value_max   rank
#  83         61208333.0       61208333.0   24.0
#  143        61500000.0       61500000.0   23.0
#  125        41979166.0       41979166.0   56.0
#  187        24500000.0       24500000.0  154.5
#  230        44395833.0       44395833.0   49.0
#  362        27562499.0       27562499.0  118.0
#  378        25541666.0       25541666.0  144.0
#  514        13258333.0       13258333.0  333.0
#  767         6166666.0        6166666.0  659.0
#
#  [9 rows x 40 columns],
#  ('England',
#   'Defender'):            Full Name  Overall  Potential  Value(in Euro) Positions Played  \
#  69       Kyle Walker       85         85        37500000               RB
#  137      Reece James       84         88        57000000           RWB,RB
#  146    Fikayo Tomori       84         90        60500000               CB
#  117  Kieran Trippier       84         84        30500000            RB,RM
#  195      John Stones       83         84        34500000               CB
#  243     Ben Chilwell       82         85        37000000           LWB,LB
#  246  Jordan Pickford       82         84        26000000               GK
#  236   Aaron Ramsdale       82         86        34500000               GK
#  308    Harry Maguire       81         82        24000000               CB
#
#      Best Position Nationality  \
#  69             RB     England
#  137           RWB     England
#  146            CB     England
#  117            RB     England
#  195            CB     England
#  243           LWB     England
#  246            GK     England
#  236            GK     England
#  308            CB     England
#
#                                             Image Link  Age  Height(in cm)  \
#  69   https://cdn.sofifa.net/players/188/377/23_60.png   32            183
#  137  https://cdn.sofifa.net/players/238/074/23_60.png   22            178
#  146  https://cdn.sofifa.net/players/232/756/23_60.png   24            185
#  117  https://cdn.sofifa.net/players/186/345/23_60.png   31            173
#  195  https://cdn.sofifa.net/players/203/574/23_60.png   28            188
#  243  https://cdn.sofifa.net/players/229/984/23_60.png   25            180
#  246  https://cdn.sofifa.net/players/204/935/23_60.png   28            185
#  236  https://cdn.sofifa.net/players/233/934/23_60.png   24            191
#  308  https://cdn.sofifa.net/players/203/263/23_60.png   29            194
#
#       ...    pretty_name_x country_of_citizenship  position  sub_position  \
#  69   ...      Kyle Walker                England  Defender    Right-Back
#  137  ...      Reece James                England  Defender    Right-Back
#  146  ...    Fikayo Tomori                England  Defender   Centre-Back
#  117  ...  Kieran Trippier                England  Defender    Right-Back
#  195  ...      John Stones                England  Defender   Centre-Back
#  243  ...     Ben Chilwell                England  Defender     Left-Back
#  246  ...  Jordan Pickford                England  Defender           NaN
#  236  ...   Aaron Ramsdale                England  Defender           NaN
#  308  ...    Harry Maguire                England  Defender   Centre-Back
#
#      date_of_birth            name  market_value_mean  market_value_min  \
#  69     1990-05-28  premier-league         33958333.0        33958333.0
#  137    1999-12-08  premier-league         36447916.0        36447916.0
#  146    1997-12-19         serie-a         28312499.0        28312499.0
#  117    1990-09-19  premier-league         23416666.0        23416666.0
#  195    1994-05-28  premier-league         38166666.0        38166666.0
#  243    1996-12-21  premier-league         42062500.0        42062500.0
#  246    1994-03-07  premier-league         28333333.0        28333333.0
#  236    1998-05-14  premier-league         16499999.0        16499999.0
#  308    1993-03-05  premier-league         48062499.0        48062499.0
#
#      market_value_max   rank
#  69        33958333.0   86.0
#  137       36447916.0   77.5
#  146       28312499.0  112.0
#  117       23416666.0  166.0
#  195       38166666.0   70.0
#  243       42062500.0   55.0
#  246       28333333.0  111.0
#  236       16499999.0  255.0
#  308       48062499.0   43.0
#
#  [9 rows x 40 columns],
#  ('Belgium',
#   'Attack'):             Full Name  Overall  Potential  Value(in Euro) Positions Played  \
#  3     Kevin De Bruyne       91         91       107500000           CM,CAM
#  45      Romelu Lukaku       86         86        68000000               ST
#  79   Yannick Carrasco       85         85        54500000               LM
#  95      Dries Mertens       84         84        18000000        CF,ST,CAM
#  120       Eden Hazard       84         84        35000000               LW
#  438    Thorgan Hazard       80         80        20500000            LM,CF
#  430      Hans Vanaken       80         80        20500000           CM,CAM
#  668  Leandro Trossard       79         79        18500000        LM,ST,CAM
#  663     Adnan Januzaj       79         79        18500000            RW,LW
#
#      Best Position Nationality  \
#  3              CM     Belgium
#  45             ST     Belgium
#  79             LM     Belgium
#  95             CF     Belgium
#  120            LW     Belgium
#  438            LM     Belgium
#  430            CM     Belgium
#  668            LM     Belgium
#  663            RW     Belgium
#
#                                             Image Link  Age  Height(in cm)  \
#  3    https://cdn.sofifa.net/players/192/985/23_60.png   31            181
#  45   https://cdn.sofifa.net/players/192/505/23_60.png   29            191
#  79   https://cdn.sofifa.net/players/208/418/23_60.png   28            181
#  95   https://cdn.sofifa.net/players/175/943/23_60.png   35            169
#  120  https://cdn.sofifa.net/players/183/277/23_60.png   31            175
#  438  https://cdn.sofifa.net/players/203/486/23_60.png   29            175
#  430  https://cdn.sofifa.net/players/200/155/23_60.png   29            195
#  668  https://cdn.sofifa.net/players/207/421/23_60.png   27            171
#  663  https://cdn.sofifa.net/players/208/330/23_60.png   27            186
#
#       ...     pretty_name_x country_of_citizenship  position  \
#  3    ...   Kevin De Bruyne                Belgium    Attack
#  45   ...     Romelu Lukaku                Belgium    Attack
#  79   ...  Yannick Carrasco                Belgium    Attack
#  95   ...     Dries Mertens                Belgium    Attack
#  120  ...       Eden Hazard                Belgium    Attack
#  438  ...    Thorgan Hazard                Belgium    Attack
#  430  ...      Hans Vanaken                Belgium    Attack
#  668  ...  Leandro Trossard                Belgium    Attack
#  663  ...     Adnan Januzaj                Belgium    Attack
#
#             sub_position date_of_birth                name  market_value_mean  \
#  3    Attacking Midfield    1991-06-28      premier-league        109791666.0
#  45       Centre-Forward    1993-05-13             serie-a         81750000.0
#  79          Left Winger    1993-09-04              laliga         30750000.0
#  95       Centre-Forward    1987-05-06           super-lig         13654166.0
#  120         Left Winger    1991-01-07              laliga         65358333.0
#  438         Left Winger    1993-03-29          bundesliga         27833333.0
#  430  Attacking Midfield    1992-08-24  jupiler-pro-league         14291666.0
#  668         Left Winger    1994-12-04      premier-league         17833333.0
#  663        Right Winger    1995-02-05              laliga         10979166.0
#
#       market_value_min market_value_max   rank
#  3         109791666.0      109791666.0    3.0
#  45         81750000.0       81750000.0    8.0
#  79         30750000.0       30750000.0   97.0
#  95         13654166.0       13654166.0  323.0
#  120        65358333.0       65358333.0   18.0
#  438        27833333.0       27833333.0  115.0
#  430        14291666.0       14291666.0  304.0
#  668        17833333.0       17833333.0  226.0
#  663        10979166.0       10979166.0  413.0
#
#  [9 rows x 40 columns],
#  ('Belgium',
#   'Midfield'):                  Full Name  Overall  Potential  Value(in Euro)  \
#  131        Youri Tielemans       84         86        52500000
#  588            Axel Witsel       79         79         8500000
#  733              Mats Rits       78         78        12500000
#  808           Dennis Praet       78         78        14000000
#  1395      Radja Nainggolan       76         76         3500000
#  1227    Leander Dendoncker       76         77         8500000
#  1645  Albert Sambi Lokonga       75         83        12500000
#  1703          Bryan Heynen       75         80         8000000
#  1560        Julien De Sart       75         76         6500000
#
#       Positions Played Best Position Nationality  \
#  131            CM,CDM            CM     Belgium
#  588         CDM,CM,CB           CDM     Belgium
#  733            CDM,CM           CDM     Belgium
#  808         CAM,CF,CM           CAM     Belgium
#  1395       CM,CAM,CDM            CM     Belgium
#  1227               CM           CDM     Belgium
#  1645           CM,CDM            CM     Belgium
#  1703           CM,CDM            CM     Belgium
#  1560           CM,CDM            CM     Belgium
#
#                                              Image Link  Age  Height(in cm)  \
#  131   https://cdn.sofifa.net/players/216/393/23_60.png   25            176
#  588   https://cdn.sofifa.net/players/177/413/23_60.png   33            186
#  733   https://cdn.sofifa.net/players/191/627/23_60.png   28            178
#  808   https://cdn.sofifa.net/players/199/652/23_60.png   28            181
#  1395  https://cdn.sofifa.net/players/178/518/23_60.png   34            177
#  1227  https://cdn.sofifa.net/players/212/501/23_60.png   27            189
#  1645  https://cdn.sofifa.net/players/241/928/23_60.png   22            183
#  1703  https://cdn.sofifa.net/players/229/659/23_60.png   25            183
#  1560  https://cdn.sofifa.net/players/217/287/23_60.png   27            187
#
#        ...         pretty_name_x country_of_citizenship  position  \
#  131   ...       Youri Tielemans                Belgium  Midfield
#  588   ...           Axel Witsel                Belgium  Midfield
#  733   ...             Mats Rits                Belgium  Midfield
#  808   ...          Dennis Praet                Belgium  Midfield
#  1395  ...      Radja Nainggolan                Belgium  Midfield
#  1227  ...    Leander Dendoncker                Belgium  Midfield
#  1645  ...  Albert Sambi Lokonga                Belgium  Midfield
#  1703  ...          Bryan Heynen                Belgium  Midfield
#  1560  ...        Julien De Sart                Belgium  Midfield
#
#              sub_position date_of_birth                name  market_value_mean  \
#  131     Central Midfield    1997-05-07      premier-league         46999999.0
#  588   Defensive Midfield    1989-01-12              laliga         15562500.0
#  733   Defensive Midfield    1993-07-18  jupiler-pro-league          4750000.0
#  808     Central Midfield    1994-05-14      premier-league         18270833.0
#  1395    Central Midfield    1988-05-04  jupiler-pro-league         10687500.0
#  1227  Defensive Midfield    1995-04-15      premier-league         26739583.0
#  1645    Central Midfield    1999-10-22      premier-league         11125000.0
#  1703    Central Midfield    1997-02-06  jupiler-pro-league          6808333.0
#  1560  Defensive Midfield    1994-12-23  jupiler-pro-league          1799999.0
#
#        market_value_min market_value_max    rank
#  131         46999999.0       46999999.0    46.0
#  588         15562500.0       15562500.0   271.0
#  733          4750000.0        4750000.0   796.0
#  808         18270833.0       18270833.0   217.0
#  1395        10687500.0       10687500.0   420.0
#  1227        26739583.0       26739583.0   125.0
#  1645        11125000.0       11125000.0   402.0
#  1703         6808333.0        6808333.0   609.0
#  1560         1799999.0        1799999.0  1359.5
#
#  [9 rows x 40 columns],
#  ('Belgium',
#   'Defender'):              Full Name  Overall  Potential  Value(in Euro) Positions Played  \
#  6     Thibaut Courtois       90         91        90000000               GK
#  114      Koen Casteels       84         85        31500000               GK
#  259  Toby Alderweireld       82         82        14500000               CB
#  337     Jan Vertonghen       81         81         7000000               CB
#  455     Simon Mignolet       80         80         3600000               GK
#  624          Matz Sels       79         80        13000000               GK
#  775   Timothy Castagne       78         80        16000000            RB,LB
#  801     Thomas Meunier       78         78        12000000            RB,RM
#  933      Jason Denayer       77         79               0               CB
#
#      Best Position Nationality  \
#  6              GK     Belgium
#  114            GK     Belgium
#  259            CB     Belgium
#  337            CB     Belgium
#  455            GK     Belgium
#  624            GK     Belgium
#  775           RWB     Belgium
#  801            RB     Belgium
#  933            CB     Belgium
#
#                                             Image Link  Age  Height(in cm)  \
#  6    https://cdn.sofifa.net/players/192/119/23_60.png   30            199
#  114  https://cdn.sofifa.net/players/192/984/23_60.png   30            197
#  259  https://cdn.sofifa.net/players/184/087/23_60.png   33            186
#  337  https://cdn.sofifa.net/players/172/871/23_60.png   35            191
#  455  https://cdn.sofifa.net/players/173/426/23_60.png   34            193
#  624  https://cdn.sofifa.net/players/199/641/23_60.png   30            190
#  775  https://cdn.sofifa.net/players/222/501/23_60.png   26            185
#  801  https://cdn.sofifa.net/players/202/371/23_60.png   30            191
#  933  https://cdn.sofifa.net/players/220/182/23_60.png   27            184
#
#       ...      pretty_name_x country_of_citizenship  position  sub_position  \
#  6    ...   Thibaut Courtois                Belgium  Defender           NaN
#  114  ...      Koen Casteels                Belgium  Defender           NaN
#  259  ...  Toby Alderweireld                Belgium  Defender   Centre-Back
#  337  ...     Jan Vertonghen                Belgium  Defender   Centre-Back
#  455  ...     Simon Mignolet                Belgium  Defender           NaN
#  624  ...          Matz Sels                Belgium  Defender           NaN
#  775  ...   Timothy Castagne                Belgium  Defender    Right-Back
#  801  ...     Thomas Meunier                Belgium  Defender    Right-Back
#  933  ...      Jason Denayer                Belgium  Defender   Centre-Back
#
#      date_of_birth                name  market_value_mean  market_value_min  \
#  6      1992-05-11              laliga         60604166.0        60604166.0
#  114    1992-06-25          bundesliga         11500000.0        11500000.0
#  259    1989-03-02  jupiler-pro-league         20041666.0        20041666.0
#  337    1987-04-24  jupiler-pro-league         10983333.0        10983333.0
#  455    1988-03-06  jupiler-pro-league          7541666.0         7541666.0
#  624    1992-02-26             ligue-1          7041666.0         7041666.0
#  775    1995-12-05      premier-league         22499999.0        22499999.0
#  801    1991-09-12          bundesliga         17562500.0        17562500.0
#  933    1995-06-28             ligue-1         14793750.0        14793750.0
#
#      market_value_max   rank
#  6         60604166.0   25.0
#  114       11500000.0  393.0
#  259       20041666.0  196.0
#  337       10983333.0  412.0
#  455        7541666.0  566.0
#  624        7041666.0  592.5
#  775       22499999.0  175.5
#  801       17562500.0  233.0
#  933       14793750.0  295.0
#
#  [9 rows x 40 columns],
#  ('Senegal',
#   'Attack'):            Full Name  Overall  Potential  Value(in Euro) Positions Played  \
#  15        Sadio Mane       89         89        99500000            LM,CF
#  546      Boulaye Dia       79         83        24500000            ST,RW
#  1070    Habib Diallo       77         78        12500000               ST
#  908     Ismaila Sarr       77         83        16500000            RM,RW
#  1976   Krepin Diatta       74         81         8500000         RM,RW,LM
#  2024     Bamba Dieng       74         80         7000000               ST
#  1998    Mbaye Diagne       74         74         4099999               ST
#  2797    Amath Ndiaye       73         74         3600000         LM,ST,RM
#  2921  Ibrahima Niane       73         78         4700000            ST,LW
#
#       Best Position Nationality  \
#  15              LM     Senegal
#  546             ST     Senegal
#  1070            ST     Senegal
#  908             RM     Senegal
#  1976            RM     Senegal
#  2024            ST     Senegal
#  1998            ST     Senegal
#  2797            LM     Senegal
#  2921            ST     Senegal
#
#                                              Image Link  Age  Height(in cm)  \
#  15    https://cdn.sofifa.net/players/208/722/23_60.png   30            174
#  546   https://cdn.sofifa.net/players/246/242/23_60.png   25            180
#  1070  https://cdn.sofifa.net/players/225/293/23_60.png   27            186
#  908   https://cdn.sofifa.net/players/235/353/23_60.png   24            185
#  1976  https://cdn.sofifa.net/players/238/227/23_60.png   23            175
#  2024  https://cdn.sofifa.net/players/261/084/23_60.png   21            178
#  1998  https://cdn.sofifa.net/players/220/131/23_60.png   30            191
#  2797  https://cdn.sofifa.net/players/233/631/23_60.png   25            173
#  2921  https://cdn.sofifa.net/players/239/025/23_60.png   23            187
#
#        ...   pretty_name_x country_of_citizenship  position    sub_position  \
#  15    ...      Sadio Mane                Senegal    Attack     Left Winger
#  546   ...     Boulaye Dia                Senegal    Attack  Centre-Forward
#  1070  ...    Habib Diallo                Senegal    Attack  Centre-Forward
#  908   ...    Ismaila Sarr                Senegal    Attack    Right Winger
#  1976  ...   Krepin Diatta                Senegal    Attack    Right Winger
#  2024  ...     Bamba Dieng                Senegal    Attack  Centre-Forward
#  1998  ...    Mbaye Diagne                Senegal    Attack  Centre-Forward
#  2797  ...    Amath Ndiaye                Senegal    Attack     Left Winger
#  2921  ...  Ibrahima Niane                Senegal    Attack  Centre-Forward
#
#       date_of_birth            name  market_value_mean  market_value_min  \
#  15      1992-04-10      bundesliga         97499999.0        97499999.0
#  546     1996-11-16         serie-a          8833333.0         8833333.0
#  1070    1995-06-18         ligue-1         10468750.0        10468750.0
#  908     1998-02-25  premier-league         22250000.0        22250000.0
#  1976    1999-02-25         ligue-1         15031250.0        15031250.0
#  2024    2000-03-23         ligue-1          6275000.0         6275000.0
#  1998    1991-10-28       super-lig          3933333.0         3933333.0
#  2797    1996-07-16          laliga          2581250.0         2581250.0
#  2921    1999-03-11         ligue-1          5178750.0         5178750.0
#
#       market_value_max    rank
#  15         97499999.0     5.0
#  546         8833333.0   494.5
#  1070       10468750.0   430.0
#  908        22250000.0   182.0
#  1976       15031250.0   287.0
#  2024        6275000.0   641.0
#  1998        3933333.0   887.0
#  2797        2581250.0  1112.0
#  2921        5178750.0   757.0
#
#  [9 rows x 40 columns],
#  ('Senegal',
#   'Midfield'):              Full Name  Overall  Potential  Value(in Euro) Positions Played  \
#  249      Idrissa Gueye       82         82        20500000           CDM,CM
#  968   Cheikhou Kouyate       77         77         7000000        CDM,CB,CM
#  1334        Pape Gueye       76         82        11000000           CDM,CM
#  2098    Nampalys Mendy       74         74         3500000           CDM,CM
#  2416      Mamadou Loum       73         78         4099999           CDM,CM
#  2641        Pathe Ciss       73         73         2700000           CDM,CM
#  3284      Badou Ndiaye       72         72         1900000           CM,CDM
#  3916   Pape Matar Sarr       71         82         4000000               CM
#  3754         Dion Lopy       71         79         4099999           CM,CDM
#
#       Best Position Nationality  \
#  249            CDM     Senegal
#  968            CDM     Senegal
#  1334           CDM     Senegal
#  2098           CDM     Senegal
#  2416            CB     Senegal
#  2641           CDM     Senegal
#  3284           CDM     Senegal
#  3916            CM     Senegal
#  3754            CM     Senegal
#
#                                              Image Link  Age  Height(in cm)  \
#  249   https://cdn.sofifa.net/players/193/474/23_60.png   32            174
#  968   https://cdn.sofifa.net/players/186/801/23_60.png   32            189
#  1334  https://cdn.sofifa.net/players/241/707/23_60.png   23            187
#  2098  https://cdn.sofifa.net/players/198/861/23_60.png   30            167
#  2416  https://cdn.sofifa.net/players/245/021/23_60.png   25            188
#  2641  https://cdn.sofifa.net/players/250/858/23_60.png   28            185
#  3284  https://cdn.sofifa.net/players/221/000/23_60.png   31            180
#  3916  https://cdn.sofifa.net/players/259/868/23_60.png   19            184
#  3754  https://cdn.sofifa.net/players/259/190/23_60.png   20            184
#
#        ...     pretty_name_x country_of_citizenship  position  \
#  249   ...     Idrissa Gueye                Senegal  Midfield
#  968   ...  Cheikhou Kouyate                Senegal  Midfield
#  1334  ...        Pape Gueye                Senegal  Midfield
#  2098  ...    Nampalys Mendy                Senegal  Midfield
#  2416  ...      Mamadou Loum                Senegal  Midfield
#  2641  ...        Pathe Ciss                Senegal  Midfield
#  3284  ...      Badou Ndiaye                Senegal  Midfield
#  3916  ...   Pape Matar Sarr                Senegal  Midfield
#  3754  ...         Dion Lopy                Senegal  Midfield
#
#              sub_position date_of_birth            name  market_value_mean  \
#  249     Central Midfield    1989-09-26  premier-league         19416666.0
#  968   Defensive Midfield    1989-12-21  premier-league          6875000.0
#  1334  Defensive Midfield    1999-01-24         ligue-1          5829166.0
#  2098  Defensive Midfield    1992-06-23  premier-league          6270833.0
#  2416  Defensive Midfield    1996-12-30          laliga          3412500.0
#  2641    Central Midfield    1994-03-16          laliga          1280208.0
#  3284    Central Midfield    1990-10-27       super-lig          4893750.0
#  3916    Central Midfield    2002-09-14  premier-league         14125000.0
#  3754  Defensive Midfield    2002-02-02         ligue-1          1800000.0
#
#        market_value_min market_value_max    rank
#  249         19416666.0       19416666.0   205.0
#  968          6875000.0        6875000.0   605.0
#  1334         5829166.0        5829166.0   694.0
#  2098         6270833.0        6270833.0   643.0
#  2416         3412500.0        3412500.0   955.5
#  2641         1280208.0        1280208.0  1525.0
#  3284         4893750.0        4893750.0   782.0
#  3916        14125000.0       14125000.0   313.0
#  3754         1800000.0        1800000.0  1358.0
#
#  [9 rows x 40 columns],
#  ('Senegal',
#   'Defender'):               Full Name  Overall  Potential  Value(in Euro) Positions Played  \
#  40    Kalidou Koulibaly       87         87        54500000               CB
#  62        Edouard Mendy       86         87        51000000               GK
#  811     Moussa Niakhate       78         80        15500000               CB
#  1072       Abdou Diallo       77         79        11500000            CB,LB
#  875        Alfred Gomis       77         79         9000000               GK
#  1130    Youssouf Sabaly       76         76         6500000            RB,RM
#  2934         Bouna Sarr       73         73         2600000            RB,RM
#  2845    Papy Djilobodji       73         73         1500000               CB
#  3630      Ismail Jakobs       71         79         4200000            LM,LB
#
#       Best Position Nationality  \
#  40              CB     Senegal
#  62              GK     Senegal
#  811             CB      France
#  1072            CB     Senegal
#  875             GK     Senegal
#  1130            RB     Senegal
#  2934            RM     Senegal
#  2845            CB     Senegal
#  3630            LM     Germany
#
#                                              Image Link  Age  Height(in cm)  \
#  40    https://cdn.sofifa.net/players/201/024/23_60.png   31            187
#  62    https://cdn.sofifa.net/players/234/642/23_60.png   30            197
#  811   https://cdn.sofifa.net/players/225/859/23_60.png   26            190
#  1072  https://cdn.sofifa.net/players/225/711/23_60.png   26            187
#  875   https://cdn.sofifa.net/players/201/976/23_60.png   28            196
#  1130  https://cdn.sofifa.net/players/215/699/23_60.png   29            173
#  2934  https://cdn.sofifa.net/players/204/472/23_60.png   30            178
#  2845  https://cdn.sofifa.net/players/197/937/23_60.png   33            193
#  3630  https://cdn.sofifa.net/players/252/293/23_60.png   22            184
#
#        ...      pretty_name_x country_of_citizenship  position  sub_position  \
#  40    ...  Kalidou Koulibaly                Senegal  Defender   Centre-Back
#  62    ...      Edouard Mendy                Senegal  Defender           NaN
#  811   ...    Moussa Niakhate                Senegal  Defender   Centre-Back
#  1072  ...       Abdou Diallo                Senegal  Defender   Centre-Back
#  875   ...       Alfred Gomis                Senegal  Defender           NaN
#  1130  ...    Youssouf Sabaly                Senegal  Defender    Right-Back
#  2934  ...         Bouna Sarr                Senegal  Defender    Right-Back
#  2845  ...    Papy Djilobodji                Senegal  Defender   Centre-Back
#  3630  ...      Ismail Jakobs                Senegal  Defender     Left-Back
#
#       date_of_birth            name  market_value_mean  market_value_min  \
#  40      1991-06-20  premier-league         55104166.0        55104166.0
#  62      1992-03-01  premier-league         20624999.0        20624999.0
#  811     1996-03-08  premier-league         13656250.0        13656250.0
#  1072    1996-05-04      bundesliga         26208333.0        26208333.0
#  875     1993-09-05         ligue-1          5299999.0         5299999.0
#  1130    1993-03-05          laliga          6562500.0         6562500.0
#  2934    1992-01-31      bundesliga          5281250.0         5281250.0
#  2845    1988-12-01       super-lig          1895833.0         1895833.0
#  3630    1999-08-17         ligue-1          4345833.0         4345833.0
#
#       market_value_max    rank
#  40         55104166.0    32.0
#  62         20624999.0   193.0
#  811        13656250.0   322.0
#  1072       26208333.0   132.0
#  875         5299999.0   747.0
#  1130        6562500.0   620.0
#  2934        5281250.0   750.0
#  2845        1895833.0  1325.0
#  3630        4345833.0   834.0
#
#  [9 rows x 40 columns],
#  ('Argentina',
#   'Attack'):             Full Name  Overall  Potential  Value(in Euro) Positions Played  \
#  0        Lionel Messi       91         91        54000000               RW
#  49       Paulo Dybala       86         86        69500000           CF,CAM
#  59   Lautaro Martinez       86         90        98500000               ST
#  119    Angel Di Maria       84         84        20000000               RW
#  178      Angel Correa       83         84        42500000         ST,RM,CF
#  347     Lucas Ocampos       81         81        27500000            RW,LW
#  416  Nicolas Gonzalez       80         85        32000000            RW,LW
#  477    Joaquin Correa       80         80        23000000            CF,ST
#  483  Emiliano Buendia       80         82        26500000        RM,RW,CAM
#
#      Best Position Nationality  \
#  0             CAM   Argentina
#  49            CAM   Argentina
#  59             ST   Argentina
#  119            RW   Argentina
#  178            CF   Argentina
#  347            RW   Argentina
#  416            LM   Argentina
#  477            RW   Argentina
#  483           CAM   Argentina
#
#                                             Image Link  Age  Height(in cm)  \
#  0    https://cdn.sofifa.net/players/158/023/23_60.png   35            169
# ...
#
#  [1 rows x 40 columns],
#  ('Costa Rica',
#   'Midfield'): Empty DataFrame
#  Columns: [Full Name, Overall, Potential, Value(in Euro), Positions Played, Best Position, Nationality, Image Link, Age, Height(in cm), TotalStats, Club Name, Wage(in Euro), Release Clause, Club Position, Club Jersey Number, Skill Moves, International Reputation, National Team Name, National Team Image Link, National Team Position, National Team Jersey Number, Finishing, Short Passing, Sprint Speed, Stamina, Strength, Penalties, World Cup, player_id, pretty_name_x, country_of_citizenship, position, sub_position, date_of_birth, name, market_value_mean, market_value_min, market_value_max, rank]
#  Index: []
#
#  [0 rows x 40 columns],
#  ('Costa Rica',
#   'Defender'):              Full Name  Overall  Potential  Value(in Euro) Positions Played  \
#  26        Keylor Navas       88         88        10000000               GK
#  1968   Cristian Gamboa       74         74         2900000               RB
#  6049   Francisco Calvo       69         69         1200000               CB
#  13990     Bryan Oviedo       62         62          275000               LB
#
#        Best Position Nationality  \
#  26               GK  Costa Rica
#  1968             RB  Costa Rica
#  6049             CB  Costa Rica
#  13990            LB  Costa Rica
#
#                                               Image Link  Age  Height(in cm)  \
#  26     https://cdn.sofifa.net/players/193/041/23_60.png   35            185
#  1968   https://cdn.sofifa.net/players/198/553/23_60.png   32            175
#  6049   https://cdn.sofifa.net/players/213/064/23_60.png   29            180
#  13990  https://cdn.sofifa.net/players/198/335/23_60.png   32            172
#
#         ...    pretty_name_x country_of_citizenship  position  sub_position  \
#  26     ...     Keylor Navas             Costa Rica  Defender           NaN
#  1968   ...  Cristian Gamboa             Costa Rica  Defender    Right-Back
#  6049   ...  Francisco Calvo             Costa Rica  Defender   Centre-Back
#  13990  ...     Bryan Oviedo             Costa Rica  Defender     Left-Back
#
#        date_of_birth         name  market_value_mean  market_value_min  \
#  26       1986-12-15      ligue-1          9249999.0         9249999.0
#  1968     1989-10-24   bundesliga           658333.0          658333.0
#  6049     1992-07-08    super-lig          1079166.0         1079166.0
#  13990    1990-02-18  superligaen           468750.0          468750.0
#
#        market_value_max    rank
#  26           9249999.0   473.0
#  1968          658333.0  1928.0
#  6049         1079166.0  1608.5
#  13990         468750.0  2146.0
#
#  [4 rows x 40 columns],
#  ('Australia',
#   'Attack'):                Full Name  Overall  Potential  Value(in Euro) Positions Played  \
#  3052        Martin Boyle       72         72         2300000            RM,ST
#  3235       Ajdin Hrustic       72         75         3100000        CM,CDM,RM
#  4736          Awer Mabil       70         70         1700000         LM,RM,LW
#  5906       Denis Genreau       69         78         3100000           CM,CAM
#  11117  Apostolos Giannou       64         64          475000               ST
#  15941          Alou Kuol       59         71          550000               ST
#
#        Best Position Nationality  \
#  3052             RM   Australia
#  3235            CAM   Australia
#  4736             LM   Australia
#  5906             CM   Australia
#  11117            ST   Australia
#  15941            ST   Australia
#
#                                               Image Link  Age  Height(in cm)  \
#  3052   https://cdn.sofifa.net/players/211/221/23_60.png   29            172
#  3235   https://cdn.sofifa.net/players/237/647/23_60.png   25            183
#  4736   https://cdn.sofifa.net/players/212/830/23_60.png   26            179
#  5906   https://cdn.sofifa.net/players/236/890/23_60.png   23            175
#  11117  https://cdn.sofifa.net/players/206/435/23_60.png   32            185
#  15941  https://cdn.sofifa.net/players/256/392/23_60.png   20            181
#
#         ...      pretty_name_x country_of_citizenship  position  \
#  3052   ...       Martin Boyle              Australia    Attack
#  3235   ...      Ajdin Hrustic              Australia    Attack
#  4736   ...         Awer Mabil              Australia    Attack
#  5906   ...      Denis Genreau              Australia    Attack
#  11117  ...  Apostolos Giannou              Australia    Attack
#  15941  ...          Alou Kuol              Australia    Attack
#
#               sub_position date_of_birth                  name  \
#  3052         Right Winger    1993-04-25  scottish-premiership
#  3235   Attacking Midfield    1996-07-05               serie-a
#  4736          Left Winger    1995-09-15                laliga
#  5906   Attacking Midfield    1999-05-21               ligue-1
#  11117      Centre-Forward    1990-01-25        super-league-1
#  15941      Centre-Forward    2001-07-05            bundesliga
#
#         market_value_mean  market_value_min market_value_max    rank
#  3052           1545833.0         1545833.0        1545833.0  1429.5
#  3235           1466666.0         1466666.0        1466666.0  1460.5
#  4736           2095833.0         2095833.0        2095833.0  1256.0
#  5906            664583.0          664583.0         664583.0  1922.5
#  11117           393791.0          393791.0         393791.0  2264.0
#  15941           237500.0          237500.0         237500.0  2574.5
#
#  [6 rows x 40 columns],
#  ('Australia',
#   'Midfield'):          Full Name  Overall  Potential  Value(in Euro) Positions Played  \
#  1147    Aaron Mooy       76         76         6000000           CM,CAM
#  7016   James Jeggo       68         68         1000000           CDM,CM
#  6901  Keanu Baccus       68         71         1600000           CM,CDM
#
#       Best Position Nationality  \
#  1147            CM   Australia
#  7016           CDM   Australia
#  6901           CDM   Australia
#
#                                              Image Link  Age  Height(in cm)  \
#  1147  https://cdn.sofifa.net/players/194/958/23_60.png   31            175
#  7016  https://cdn.sofifa.net/players/203/225/23_60.png   30            178
#  6901  https://cdn.sofifa.net/players/237/005/23_60.png   24            176
#
#        ...  pretty_name_x country_of_citizenship  position        sub_position  \
#  1147  ...     Aaron Mooy              Australia  Midfield    Central Midfield
#  7016  ...    James Jeggo              Australia  Midfield  Defensive Midfield
#  6901  ...   Keanu Baccus              Australia  Midfield  Defensive Midfield
#
#       date_of_birth                  name  market_value_mean  market_value_min  \
#  1147    1990-09-15  scottish-premiership          8500000.0         8500000.0
#  7016    1992-02-12    jupiler-pro-league           850000.0          850000.0
#  6901    1998-06-07  scottish-premiership           437500.0          437500.0
#
#       market_value_max    rank
#  1147        8500000.0   511.5
#  7016         850000.0  1756.0
#  6901         437500.0  2186.0
#
#  [3 rows x 40 columns],
#  ('Australia',
#   'Defender'):                Full Name  Overall  Potential  Value(in Euro) Positions Played  \
#  791          Mathew Ryan       78         78         9500000               GK
#  3106     Trent Sainsbury       72         72               0               CB
#  5202         Aziz Behich       70         70         1200000               LB
#  4979       Danny Vukovic       70         70          180000               GK
#  5445     Lawrence Thomas       69         69          925000               GK
#  5264     Mark Birighitti       69         69          750000               GK
#  6763  Nathaniel Atkinson       68         76         2600000           RWB,RB
#  7720      Jason Davidson       67         67          750000           LB,LWB
#  7700          Kye Rowles       67         73         1500000               CB
#
#       Best Position Nationality  \
#  791             GK   Australia
#  3106            CB   Australia
#  5202            LB   Australia
#  4979            GK   Australia
#  5445            GK   Australia
#  5264            GK   Australia
#  6763            RM   Australia
#  7720            LB   Australia
#  7700            CB   Australia
#
#                                              Image Link  Age  Height(in cm)  \
#  791   https://cdn.sofifa.net/players/199/005/23_60.png   30            184
#  3106  https://cdn.sofifa.net/players/199/000/23_60.png   30            183
#  5202  https://cdn.sofifa.net/players/202/157/23_60.png   31            170
#  4979  https://cdn.sofifa.net/players/181/481/23_60.png   37            187
#  5445  https://cdn.sofifa.net/players/203/423/23_60.png   30            191
#  5264  https://cdn.sofifa.net/players/188/278/23_60.png   31            189
#  6763  https://cdn.sofifa.net/players/241/861/23_60.png   23            181
#  7720  https://cdn.sofifa.net/players/197/831/23_60.png   31            180
#  7700  https://cdn.sofifa.net/players/233/931/23_60.png   24            183
#
#        ...       pretty_name_x country_of_citizenship  position  sub_position  \
#  791   ...         Mathew Ryan              Australia  Defender           NaN
#  3106  ...     Trent Sainsbury              Australia  Defender   Centre-Back
#  5202  ...         Aziz Behich              Australia  Defender     Left-Back
#  4979  ...       Danny Vukovic              Australia  Defender           NaN
#  5445  ...     Lawrence Thomas              Australia  Defender           NaN
#  5264  ...     Mark Birighitti              Australia  Defender           NaN
#  6763  ...  Nathaniel Atkinson              Australia  Defender    Right-Back
#  7720  ...      Jason Davidson              Australia  Defender     Left-Back
#  7700  ...          Kye Rowles              Australia  Defender   Centre-Back
#
#       date_of_birth                  name  market_value_mean  market_value_min  \
#  791     1992-04-08           superligaen          7166666.0         7166666.0
#  3106    1992-01-05    jupiler-pro-league           786250.0          786250.0
#  5202    1990-12-16  scottish-premiership           793229.0          793229.0
#  4979    1985-03-27            eredivisie           601875.0          601875.0
#  5445    1992-05-09           superligaen           624375.0          624375.0
#  5264    1991-04-17  scottish-premiership           421875.0          421875.0
#  6763    1999-06-13  scottish-premiership           662500.0          662500.0
#  7720    1991-06-29    jupiler-pro-league           604166.0          604166.0
#  7700    1998-06-24  scottish-premiership           446875.0          446875.0
#
#       market_value_max    rank
#  791         7166666.0   584.0
#  3106         786250.0  1809.0
#  5202         793229.0  1802.0
#  4979         601875.0  1976.0
#  5445         624375.0  1956.0
#  5264         421875.0  2213.0
#  6763         662500.0  1924.0
#  7720         604166.0  1971.5
#  7700         446875.0  2175.5
#
#  [9 rows x 40 columns],
#  ('Brazil',
#   'Attack'):              Full Name  Overall  Potential  Value(in Euro) Positions Played  \
#  828        Luiz Araujo       78         78        15500000        RM,LM,CAM
#  712     Junior Messias       78         78        11500000            RW,RM
#  10977  Bruno Rodrigues       64         77         1400000               CB
#
#        Best Position Nationality  \
#  828              RM      Brazil
#  712              RW      Brazil
#  10977            CB    Portugal
#
#                                               Image Link  Age  Height(in cm)  \
#  828    https://cdn.sofifa.net/players/234/128/23_60.png   26            175
#  712    https://cdn.sofifa.net/players/240/938/23_60.png   31            179
#  10977  https://cdn.sofifa.net/players/260/167/23_60.png   21            192
#
#         ...    pretty_name_x country_of_citizenship  position  sub_position  \
#  828    ...      Luiz Araujo                 Brazil    Attack  Right Winger
#  712    ...   Junior Messias                 Brazil    Attack  Right Winger
#  10977  ...  Bruno Rodrigues                 Brazil    Attack   Left Winger
#
#        date_of_birth                name  market_value_mean  market_value_min  \
#  828      1996-06-02             ligue-1          7125000.0         7125000.0
#  712      1991-05-13             serie-a          3209375.0         3209375.0
#  10977    1997-03-07  liga-portugal-bwin           652500.0          652500.0
#
#        market_value_max    rank
#  828          7125000.0   587.0
#  712          3209375.0   986.0
#  10977         652500.0  1929.5
#
#  [3 rows x 40 columns],
#  ('Brazil',
#   'Midfield'):           Full Name  Overall  Potential  Value(in Euro) Positions Played  \
#  7244  Victor Bobsin       67         78         2200000           CDM,CM
#
#       Best Position Nationality  \
#  7244            CM      Brazil
#
#                                              Image Link  Age  Height(in cm)  \
#  7244  https://cdn.sofifa.net/players/263/787/23_60.png   22            185
#
#        ...  pretty_name_x country_of_citizenship  position        sub_position  \
#  7244  ...  Victor Bobsin                 Brazil  Midfield  Defensive Midfield
#
#       date_of_birth                name  market_value_mean  market_value_min  \
#  7244    2000-01-12  liga-portugal-bwin           800000.0          800000.0
#
#       market_value_max    rank
#  7244         800000.0  1795.5
#
#  [1 rows x 40 columns],
#  ('Brazil',
#   'Defender'):              Full Name  Overall  Potential  Value(in Euro) Positions Played  \
#  813     Andrei Girotto       78         78        11500000           CB,CDM
#  1448       Rodrigo Ely       75         75         4800000               CB
#  4666  Lucas Possignolo       70         72         1600000               CB
#  6112      Lucas Galvao       69         69          950000            CB,LB
#  6163      Rodrigo Guth       68         75         2300000               CB
#
#       Best Position Nationality  \
#  813             CB      Brazil
#  1448            CB      Brazil
#  4666            CB      Brazil
#  6112            CB      Brazil
#  6163            CB      Brazil
#
#                                              Image Link  Age  Height(in cm)  \
#  813   https://cdn.sofifa.net/players/226/515/23_60.png   30            186
#  1448  https://cdn.sofifa.net/players/202/445/23_60.png   28            188
#  4666  https://cdn.sofifa.net/players/238/862/23_60.png   28            188
#  6112  https://cdn.sofifa.net/players/230/981/23_60.png   31            182
#  6163  https://cdn.sofifa.net/players/263/556/23_60.png   21            191
#
#        ...     pretty_name_x country_of_citizenship  position  sub_position  \
#  813   ...    Andrei Girotto                 Brazil  Defender   Centre-Back
#  1448  ...       Rodrigo Ely                 Brazil  Defender   Centre-Back
#  4666  ...  Lucas Possignolo                 Brazil  Defender   Centre-Back
#  6112  ...      Lucas Galvao                 Brazil  Defender   Centre-Back
#  6163  ...      Rodrigo Guth                 Brazil  Defender   Centre-Back
#
#       date_of_birth                name  market_value_mean  market_value_min  \
#  813     1992-02-17             ligue-1          4124999.0         4124999.0
#  1448    1993-11-03              laliga          2237499.0         2237499.0
#  4666    1994-05-11  liga-portugal-bwin           712500.0          712500.0
#  6112    1991-06-22      super-league-1           798750.0          798750.0
#  6163    2000-11-10          eredivisie           440625.0          440625.0
#
#       market_value_max    rank
#  813         4124999.0   858.0
#  1448        2237499.0  1199.0
#  4666         712500.0  1874.5
#  6112         798750.0  1798.0
#  6163         440625.0  2183.0
#
#  [5 rows x 40 columns]}
